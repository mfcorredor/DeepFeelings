# %% [markdown]
# # Donwload training dataset

# %% [markdown]
# https://github.com/cardiffnlp/tweeteval/tree/main/datasets/sentiment

# %%
import pandas as pd

# %%
test_labels = pd.read_csv("../raw_data/cardiffnlp_tweeteval/test_labels.csv")
test_text = pd.read_csv("../raw_data/cardiffnlp_tweeteval/test_text.csv")
train_labels = pd.read_csv("../raw_data/cardiffnlp_tweeteval/train_labels.csv")
val_labels = pd.read_csv("../raw_data/cardiffnlp_tweeteval/val_labels.csv")
val_text = pd.read_csv("../raw_data/cardiffnlp_tweeteval/val_text.csv")

# %%
train_text = pd.read_csv("../raw_data/cardiffnlp_tweeteval/train_text.txt", sep="\" \"", header=None)
train_text

# %% [markdown]
# # Import some models trained

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import AutoModelForSeq2SeqLM, AutoConfig, pipeline

# %%
def get_model_elements(model_path: str, model_type: str):
    model, config = None, None
    if model_type == 'classifier':
        model = AutoModelForSequenceClassification.from_pretrained(model_path)
        config = AutoConfig.from_pretrained(model_path)
    elif model_type == 'generator':
        model = AutoModelForSeq2SeqLM.from_pretrained(model_path)
    else:
        print(f'ERROR: model type {model_type} not suppported')
        return
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    return tokenizer, model, config

# %%
sentiment_path = 'cardiffnlp/twitter-roberta-base-sentiment'

sentiment_tokenizer, sentiment_model, sentiment_config = \
            get_model_elements(sentiment_path, 'classifier')
        
        # Emotion pipeline: return e.g {'sadness': ..., 'joy': ..., 'anger': ..,
        #                               'disgust': ..., 'fear': ..., 'surprise': ...}
        
emotions_path = 'Emanuel/bertweet-emotion-base'
emotions_tokenizer, emotions_model, emotions_config = \
            get_model_elements(emotions_path, 'classifier')
# Out:
# Downloading:   0%|          | 0.00/747 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/476M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/515M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/359 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/824k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0

# %%
from typing import List, Dict

# %%
def get_scores(text: str, tokenizer, model, config, keys: List[str]) -> Dict[str, float]:
    """
    Get score (sentiment or emotions for each text in `texts`
    Args:
        text: text to score
        tokenizer: Tokenizer for each input text
        model: Classification model for tokenized texts
        config: Classification config (output label mapping) from `AutoConfig`
        keys: List containing "better" values than `config` label, aligned with
            them in alphabetical order
    Returns: dict containing `text`'s score for each `model`'s output label
    """
    encoded_input = tokenizer(text, return_tensors='pt')
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    result = {config.id2label[ranking[i]]: scores[ranking[i]] for i in range(scores.shape[0])}
    result = dict(sorted(result.items()))
    result = {k: float(v) for k, v in zip(keys, result.values())}
    return result

# %% [markdown]
# Trying the model with some tweets:

# %%
import pandas as pd
import re
import string
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import text_to_word_sequence

def clean_text(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation,
    remove words containing numbers, remove numbers.'''
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = ''.join([i for i in text if not i.isdigit()])
    return text

# %%
X_pred = pd.read_csv("../raw_data/tweets.csv")
X_pred.rename(columns = {'2022-05-31 15:38:40.948508':'date', "@Apple Pricey. That's iPhone.": "text" }, inplace = True)
X_pred
# Out:
#                             date  \
# 0     2022-05-31 15:38:40.948508
# 1     2022-05-31 15:38:40.948508
# 2     2022-05-31 15:38:40.948508
# 3     2022-05-31 15:38:40.948508
# 4     2022-05-31 15:38:40.948508
# ...                          ...
# 1098  2022-05-31 15:38:40.948508
# 1099  2022-05-31 15:38:40.948508
# 1100  2022-05-31 15:38:40.948508
# 1101  2022-05-31 15:38:40.948508
# 1102  2022-05-31 15:38:40.948508
#
#                                                    text
# 0     No there is nothing you can immutably claim at...
# 1     @Brueck1988 @Apple Might need to call for a tu...
# 2     Guys I have a question. If @Apple states that ...
# 3     @Apple is also happy to give access to your ac...
# 4     //End of Thread//  If you enjoyed this story, ...
# ...                                                 ...
# 1098        @Apple needs to buy @Mullen_USA NOW! @Tesla
# 1099  @rfog42 @tim_cook @Apple 🤣🤣🤣 https://t.co/A8Bj...
# 1100  @JudiciaryGOP This country is bathing in guns ...
# 1101  Why doesn’t the #iphone autocorrect “constipat...
# 1102  @MikeyManziel @Apple Mines been buggy all week...
#
# [1103 rows x 2 columns]

# %%
X_pred["text"] = X_pred["text"].apply(clean_text)
X_pred
# Out:
#                             date  \
# 0     2022-05-31 15:38:40.948508
# 1     2022-05-31 15:38:40.948508
# 2     2022-05-31 15:38:40.948508
# 3     2022-05-31 15:38:40.948508
# 4     2022-05-31 15:38:40.948508
# ...                          ...
# 1098  2022-05-31 15:38:40.948508
# 1099  2022-05-31 15:38:40.948508
# 1100  2022-05-31 15:38:40.948508
# 1101  2022-05-31 15:38:40.948508
# 1102  2022-05-31 15:38:40.948508
#
#                                                    text
# 0     no there is nothing you can immutably claim at...
# 1      apple might need to call for a tutorial on th...
# 2     guys i have a question if apple states that th...
# 3     apple is also happy to give access to your acc...
# 4     end of thread  if you enjoyed this story make ...
# ...                                                 ...
# 1098             apple needs to buy mullenusa now tesla
# 1099                                 timcook apple 🤣🤣🤣
# 1100  judiciarygop this country is bathing in guns a...
# 1101  why doesn’t the iphone autocorrect “constipate...
# 1102  mikeymanziel apple mines been buggy all week a...
#
# [1103 rows x 2 columns]

# %%
ls_train = X_pred["text"].tolist()
X_pred = [text_to_word_sequence(i) for i in ls_train]
X_pred
# Out:
# [['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['apple',
#   'might',
#   'need',
#   'to',
#   'call',
#   'for',
#   'a',
#   'tutorial',
#   'on',
#   'that',
#   'laterbout',
#   'to',
#   'lose',
#   'my',
#   'damn',
#   'mind'],
#  ['guys',
#   'i',
#   'have',
#   'a',
#   'question',
#   'if',
#   'apple',
#   'states',
#   'that',
#   'the',
#   'reason',
#   'why',
#   'they',
#   'are',
#   'not',
#   'including',
#   'any',
#   'charging',
#   'bricks',
#   'on',
#   'their',
#   'iphones',
#   'but',
#   'for',
#   'ipads',
#   'they',
#   'are',
#   'including',
#   'one',
#   'just',
#   'because',
#   'its',
#   'so',
#   'expensive',
#   'so',
#   'where',
#   'is',
#   'saving',
#   'the',
#   'environment',
#   'in',
#   'that',
#   'anyone',
#   'thank',
#   'you'],
#  ['apple',
#   'is',
#   'also',
#   'happy',
#   'to',
#   'give',
#   'access',
#   'to',
#   'your',
#   'accounts',
#   'for',
#   'years',
#   'i',
#   'can',
#   'prove',
#   'for',
#   'example',
#   'that',
#   'as',
#   'you',
#   'are',
#   'typing',
#   'into',
#   'the',
#   'notes',
#   'app',
#   'pages',
#   'app',
#   'and',
#   'many',
#   'others',
#   'that',
#   'the',
#   'govt',
#   'can',
#   'watch',
#   'you',
#   'as',
#   'you',
#   'do',
#   'it',
#   'in',
#   'real',
#   'time',
#   'it',
#   'is',
#   'more',
#   'than',
#   'unencrypted',
#   'icloud',
#   'backups',
#   'more',
#   'on',
#   'this',
#   'soon…'],
#  ['end',
#   'of',
#   'thread',
#   'if',
#   'you',
#   'enjoyed',
#   'this',
#   'story',
#   'make',
#   'sure',
#   'to',
#   'rt',
#   'and',
#   'follow',
#   'mbitpodcast',
#   'lets',
#   'see',
#   'if',
#   'we',
#   'can',
#   'get',
#   'this',
#   'in',
#   'the',
#   'hands',
#   'of',
#   'ericsyuan',
#   '🚀',
#   'cc',
#   'zoom',
#   'webex',
#   'cisco',
#   'microsoft',
#   'apple',
#   'emergencecap',
#   'yahoobusiness',
#   'business'],
#  ['kyzef',
#   'justape',
#   'crazycatznft',
#   'midnightpanthrs',
#   'cyberdoodlekids',
#   'poyonft',
#   'cayalaxd',
#   'apple'],
#  ['thank',
#   'you',
#   'apple',
#   'for',
#   'land',
#   'grabbing',
#   'port',
#   'and',
#   'breaking',
#   'my',
#   'docker',
#   'compose',
#   'scripts',
#   'really',
#   'love',
#   'spending',
#   'a',
#   'few',
#   'hours',
#   'wondering',
#   'why',
#   'what',
#   'worked',
#   'yesterday',
#   'doesnt',
#   'work',
#   'today'],
#  ['sayssaxo', 'apple'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['apple',
#   'might',
#   'need',
#   'to',
#   'call',
#   'for',
#   'a',
#   'tutorial',
#   'on',
#   'that',
#   'laterbout',
#   'to',
#   'lose',
#   'my',
#   'damn',
#   'mind'],
#  ['guys',
#   'i',
#   'have',
#   'a',
#   'question',
#   'if',
#   'apple',
#   'states',
#   'that',
#   'the',
#   'reason',
#   'why',
#   'they',
#   'are',
#   'not',
#   'including',
#   'any',
#   'charging',
#   'bricks',
#   'on',
#   'their',
#   'iphones',
#   'but',
#   'for',
#   'ipads',
#   'they',
#   'are',
#   'including',
#   'one',
#   'just',
#   'because',
#   'its',
#   'so',
#   'expensive',
#   'so',
#   'where',
#   'is',
#   'saving',
#   'the',
#   'environment',
#   'in',
#   'that',
#   'anyone',
#   'thank',
#   'you'],
#  ['apple',
#   'is',
#   'also',
#   'happy',
#   'to',
#   'give',
#   'access',
#   'to',
#   'your',
#   'accounts',
#   'for',
#   'years',
#   'i',
#   'can',
#   'prove',
#   'for',
#   'example',
#   'that',
#   'as',
#   'you',
#   'are',
#   'typing',
#   'into',
#   'the',
#   'notes',
#   'app',
#   'pages',
#   'app',
#   'and',
#   'many',
#   'others',
#   'that',
#   'the',
#   'govt',
#   'can',
#   'watch',
#   'you',
#   'as',
#   'you',
#   'do',
#   'it',
#   'in',
#   'real',
#   'time',
#   'it',
#   'is',
#   'more',
#   'than',
#   'unencrypted',
#   'icloud',
#   'backups',
#   'more',
#   'on',
#   'this',
#   'soon…'],
#  ['end',
#   'of',
#   'thread',
#   'if',
#   'you',
#   'enjoyed',
#   'this',
#   'story',
#   'make',
#   'sure',
#   'to',
#   'rt',
#   'and',
#   'follow',
#   'mbitpodcast',
#   'lets',
#   'see',
#   'if',
#   'we',
#   'can',
#   'get',
#   'this',
#   'in',
#   'the',
#   'hands',
#   'of',
#   'ericsyuan',
#   '🚀',
#   'cc',
#   'zoom',
#   'webex',
#   'cisco',
#   'microsoft',
#   'apple',
#   'emergencecap',
#   'yahoobusiness',
#   'business'],
#  ['kyzef',
#   'justape',
#   'crazycatznft',
#   'midnightpanthrs',
#   'cyberdoodlekids',
#   'poyonft',
#   'cayalaxd',
#   'apple'],
#  ['thank',
#   'you',
#   'apple',
#   'for',
#   'land',
#   'grabbing',
#   'port',
#   'and',
#   'breaking',
#   'my',
#   'docker',
#   'compose',
#   'scripts',
#   'really',
#   'love',
#   'spending',
#   'a',
#   'few',
#   'hours',
#   'wondering',
#   'why',
#   'what',
#   'worked',
#   'yesterday',
#   'doesnt',
#   'work',
#   'today'],
#  ['sayssaxo', 'apple'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['apple',
#   'might',
#   'need',
#   'to',
#   'call',
#   'for',
#   'a',
#   'tutorial',
#   'on',
#   'that',
#   'laterbout',
#   'to',
#   'lose',
#   'my',
#   'damn',
#   'mind'],
#  ['guys',
#   'i',
#   'have',
#   'a',
#   'question',
#   'if',
#   'apple',
#   'states',
#   'that',
#   'the',
#   'reason',
#   'why',
#   'they',
#   'are',
#   'not',
#   'including',
#   'any',
#   'charging',
#   'bricks',
#   'on',
#   'their',
#   'iphones',
#   'but',
#   'for',
#   'ipads',
#   'they',
#   'are',
#   'including',
#   'one',
#   'just',
#   'because',
#   'its',
#   'so',
#   'expensive',
#   'so',
#   'where',
#   'is',
#   'saving',
#   'the',
#   'environment',
#   'in',
#   'that',
#   'anyone',
#   'thank',
#   'you'],
#  ['apple',
#   'is',
#   'also',
#   'happy',
#   'to',
#   'give',
#   'access',
#   'to',
#   'your',
#   'accounts',
#   'for',
#   'years',
#   'i',
#   'can',
#   'prove',
#   'for',
#   'example',
#   'that',
#   'as',
#   'you',
#   'are',
#   'typing',
#   'into',
#   'the',
#   'notes',
#   'app',
#   'pages',
#   'app',
#   'and',
#   'many',
#   'others',
#   'that',
#   'the',
#   'govt',
#   'can',
#   'watch',
#   'you',
#   'as',
#   'you',
#   'do',
#   'it',
#   'in',
#   'real',
#   'time',
#   'it',
#   'is',
#   'more',
#   'than',
#   'unencrypted',
#   'icloud',
#   'backups',
#   'more',
#   'on',
#   'this',
#   'soon…'],
#  ['end',
#   'of',
#   'thread',
#   'if',
#   'you',
#   'enjoyed',
#   'this',
#   'story',
#   'make',
#   'sure',
#   'to',
#   'rt',
#   'and',
#   'follow',
#   'mbitpodcast',
#   'lets',
#   'see',
#   'if',
#   'we',
#   'can',
#   'get',
#   'this',
#   'in',
#   'the',
#   'hands',
#   'of',
#   'ericsyuan',
#   '🚀',
#   'cc',
#   'zoom',
#   'webex',
#   'cisco',
#   'microsoft',
#   'apple',
#   'emergencecap',
#   'yahoobusiness',
#   'business'],
#  ['kyzef',
#   'justape',
#   'crazycatznft',
#   'midnightpanthrs',
#   'cyberdoodlekids',
#   'poyonft',
#   'cayalaxd',
#   'apple'],
#  ['thank',
#   'you',
#   'apple',
#   'for',
#   'land',
#   'grabbing',
#   'port',
#   'and',
#   'breaking',
#   'my',
#   'docker',
#   'compose',
#   'scripts',
#   'really',
#   'love',
#   'spending',
#   'a',
#   'few',
#   'hours',
#   'wondering',
#   'why',
#   'what',
#   'worked',
#   'yesterday',
#   'doesnt',
#   'work',
#   'today'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['apple',
#   'might',
#   'need',
#   'to',
#   'call',
#   'for',
#   'a',
#   'tutorial',
#   'on',
#   'that',
#   'laterbout',
#   'to',
#   'lose',
#   'my',
#   'damn',
#   'mind'],
#  ['guys',
#   'i',
#   'have',
#   'a',
#   'question',
#   'if',
#   'apple',
#   'states',
#   'that',
#   'the',
#   'reason',
#   'why',
#   'they',
#   'are',
#   'not',
#   'including',
#   'any',
#   'charging',
#   'bricks',
#   'on',
#   'their',
#   'iphones',
#   'but',
#   'for',
#   'ipads',
#   'they',
#   'are',
#   'including',
#   'one',
#   'just',
#   'because',
#   'its',
#   'so',
#   'expensive',
#   'so',
#   'where',
#   'is',
#   'saving',
#   'the',
#   'environment',
#   'in',
#   'that',
#   'anyone',
#   'thank',
#   'you'],
#  ['apple',
#   'is',
#   'also',
#   'happy',
#   'to',
#   'give',
#   'access',
#   'to',
#   'your',
#   'accounts',
#   'for',
#   'years',
#   'i',
#   'can',
#   'prove',
#   'for',
#   'example',
#   'that',
#   'as',
#   'you',
#   'are',
#   'typing',
#   'into',
#   'the',
#   'notes',
#   'app',
#   'pages',
#   'app',
#   'and',
#   'many',
#   'others',
#   'that',
#   'the',
#   'govt',
#   'can',
#   'watch',
#   'you',
#   'as',
#   'you',
#   'do',
#   'it',
#   'in',
#   'real',
#   'time',
#   'it',
#   'is',
#   'more',
#   'than',
#   'unencrypted',
#   'icloud',
#   'backups',
#   'more',
#   'on',
#   'this',
#   'soon…'],
#  ['end',
#   'of',
#   'thread',
#   'if',
#   'you',
#   'enjoyed',
#   'this',
#   'story',
#   'make',
#   'sure',
#   'to',
#   'rt',
#   'and',
#   'follow',
#   'mbitpodcast',
#   'lets',
#   'see',
#   'if',
#   'we',
#   'can',
#   'get',
#   'this',
#   'in',
#   'the',
#   'hands',
#   'of',
#   'ericsyuan',
#   '🚀',
#   'cc',
#   'zoom',
#   'webex',
#   'cisco',
#   'microsoft',
#   'apple',
#   'emergencecap',
#   'yahoobusiness',
#   'business'],
#  ['kyzef',
#   'justape',
#   'crazycatznft',
#   'midnightpanthrs',
#   'cyberdoodlekids',
#   'poyonft',
#   'cayalaxd',
#   'apple'],
#  ['thank',
#   'you',
#   'apple',
#   'for',
#   'land',
#   'grabbing',
#   'port',
#   'and',
#   'breaking',
#   'my',
#   'docker',
#   'compose',
#   'scripts',
#   'really',
#   'love',
#   'spending',
#   'a',
#   'few',
#   'hours',
#   'wondering',
#   'why',
#   'what',
#   'worked',
#   'yesterday',
#   'doesnt',
#   'work',
#   'today'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['apple',
#   'might',
#   'need',
#   'to',
#   'call',
#   'for',
#   'a',
#   'tutorial',
#   'on',
#   'that',
#   'laterbout',
#   'to',
#   'lose',
#   'my',
#   'damn',
#   'mind'],
#  ['guys',
#   'i',
#   'have',
#   'a',
#   'question',
#   'if',
#   'apple',
#   'states',
#   'that',
#   'the',
#   'reason',
#   'why',
#   'they',
#   'are',
#   'not',
#   'including',
#   'any',
#   'charging',
#   'bricks',
#   'on',
#   'their',
#   'iphones',
#   'but',
#   'for',
#   'ipads',
#   'they',
#   'are',
#   'including',
#   'one',
#   'just',
#   'because',
#   'its',
#   'so',
#   'expensive',
#   'so',
#   'where',
#   'is',
#   'saving',
#   'the',
#   'environment',
#   'in',
#   'that',
#   'anyone',
#   'thank',
#   'you'],
#  ['apple',
#   'is',
#   'also',
#   'happy',
#   'to',
#   'give',
#   'access',
#   'to',
#   'your',
#   'accounts',
#   'for',
#   'years',
#   'i',
#   'can',
#   'prove',
#   'for',
#   'example',
#   'that',
#   'as',
#   'you',
#   'are',
#   'typing',
#   'into',
#   'the',
#   'notes',
#   'app',
#   'pages',
#   'app',
#   'and',
#   'many',
#   'others',
#   'that',
#   'the',
#   'govt',
#   'can',
#   'watch',
#   'you',
#   'as',
#   'you',
#   'do',
#   'it',
#   'in',
#   'real',
#   'time',
#   'it',
#   'is',
#   'more',
#   'than',
#   'unencrypted',
#   'icloud',
#   'backups',
#   'more',
#   'on',
#   'this',
#   'soon…'],
#  ['end',
#   'of',
#   'thread',
#   'if',
#   'you',
#   'enjoyed',
#   'this',
#   'story',
#   'make',
#   'sure',
#   'to',
#   'rt',
#   'and',
#   'follow',
#   'mbitpodcast',
#   'lets',
#   'see',
#   'if',
#   'we',
#   'can',
#   'get',
#   'this',
#   'in',
#   'the',
#   'hands',
#   'of',
#   'ericsyuan',
#   '🚀',
#   'cc',
#   'zoom',
#   'webex',
#   'cisco',
#   'microsoft',
#   'apple',
#   'emergencecap',
#   'yahoobusiness',
#   'business'],
#  ['kyzef',
#   'justape',
#   'crazycatznft',
#   'midnightpanthrs',
#   'cyberdoodlekids',
#   'poyonft',
#   'cayalaxd',
#   'apple'],
#  ['thank',
#   'you',
#   'apple',
#   'for',
#   'land',
#   'grabbing',
#   'port',
#   'and',
#   'breaking',
#   'my',
#   'docker',
#   'compose',
#   'scripts',
#   'really',
#   'love',
#   'spending',
#   'a',
#   'few',
#   'hours',
#   'wondering',
#   'why',
#   'what',
#   'worked',
#   'yesterday',
#   'doesnt',
#   'work',
#   'today'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['apple',
#   'might',
#   'need',
#   'to',
#   'call',
#   'for',
#   'a',
#   'tutorial',
#   'on',
#   'that',
#   'laterbout',
#   'to',
#   'lose',
#   'my',
#   'damn',
#   'mind'],
#  ['guys',
#   'i',
#   'have',
#   'a',
#   'question',
#   'if',
#   'apple',
#   'states',
#   'that',
#   'the',
#   'reason',
#   'why',
#   'they',
#   'are',
#   'not',
#   'including',
#   'any',
#   'charging',
#   'bricks',
#   'on',
#   'their',
#   'iphones',
#   'but',
#   'for',
#   'ipads',
#   'they',
#   'are',
#   'including',
#   'one',
#   'just',
#   'because',
#   'its',
#   'so',
#   'expensive',
#   'so',
#   'where',
#   'is',
#   'saving',
#   'the',
#   'environment',
#   'in',
#   'that',
#   'anyone',
#   'thank',
#   'you'],
#  ['apple',
#   'is',
#   'also',
#   'happy',
#   'to',
#   'give',
#   'access',
#   'to',
#   'your',
#   'accounts',
#   'for',
#   'years',
#   'i',
#   'can',
#   'prove',
#   'for',
#   'example',
#   'that',
#   'as',
#   'you',
#   'are',
#   'typing',
#   'into',
#   'the',
#   'notes',
#   'app',
#   'pages',
#   'app',
#   'and',
#   'many',
#   'others',
#   'that',
#   'the',
#   'govt',
#   'can',
#   'watch',
#   'you',
#   'as',
#   'you',
#   'do',
#   'it',
#   'in',
#   'real',
#   'time',
#   'it',
#   'is',
#   'more',
#   'than',
#   'unencrypted',
#   'icloud',
#   'backups',
#   'more',
#   'on',
#   'this',
#   'soon…'],
#  ['end',
#   'of',
#   'thread',
#   'if',
#   'you',
#   'enjoyed',
#   'this',
#   'story',
#   'make',
#   'sure',
#   'to',
#   'rt',
#   'and',
#   'follow',
#   'mbitpodcast',
#   'lets',
#   'see',
#   'if',
#   'we',
#   'can',
#   'get',
#   'this',
#   'in',
#   'the',
#   'hands',
#   'of',
#   'ericsyuan',
#   '🚀',
#   'cc',
#   'zoom',
#   'webex',
#   'cisco',
#   'microsoft',
#   'apple',
#   'emergencecap',
#   'yahoobusiness',
#   'business'],
#  ['kyzef',
#   'justape',
#   'crazycatznft',
#   'midnightpanthrs',
#   'cyberdoodlekids',
#   'poyonft',
#   'cayalaxd',
#   'apple'],
#  ['thank',
#   'you',
#   'apple',
#   'for',
#   'land',
#   'grabbing',
#   'port',
#   'and',
#   'breaking',
#   'my',
#   'docker',
#   'compose',
#   'scripts',
#   'really',
#   'love',
#   'spending',
#   'a',
#   'few',
#   'hours',
#   'wondering',
#   'why',
#   'what',
#   'worked',
#   'yesterday',
#   'doesnt',
#   'work',
#   'today'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['apple',
#   'might',
#   'need',
#   'to',
#   'call',
#   'for',
#   'a',
#   'tutorial',
#   'on',
#   'that',
#   'laterbout',
#   'to',
#   'lose',
#   'my',
#   'damn',
#   'mind'],
#  ['guys',
#   'i',
#   'have',
#   'a',
#   'question',
#   'if',
#   'apple',
#   'states',
#   'that',
#   'the',
#   'reason',
#   'why',
#   'they',
#   'are',
#   'not',
#   'including',
#   'any',
#   'charging',
#   'bricks',
#   'on',
#   'their',
#   'iphones',
#   'but',
#   'for',
#   'ipads',
#   'they',
#   'are',
#   'including',
#   'one',
#   'just',
#   'because',
#   'its',
#   'so',
#   'expensive',
#   'so',
#   'where',
#   'is',
#   'saving',
#   'the',
#   'environment',
#   'in',
#   'that',
#   'anyone',
#   'thank',
#   'you'],
#  ['apple',
#   'is',
#   'also',
#   'happy',
#   'to',
#   'give',
#   'access',
#   'to',
#   'your',
#   'accounts',
#   'for',
#   'years',
#   'i',
#   'can',
#   'prove',
#   'for',
#   'example',
#   'that',
#   'as',
#   'you',
#   'are',
#   'typing',
#   'into',
#   'the',
#   'notes',
#   'app',
#   'pages',
#   'app',
#   'and',
#   'many',
#   'others',
#   'that',
#   'the',
#   'govt',
#   'can',
#   'watch',
#   'you',
#   'as',
#   'you',
#   'do',
#   'it',
#   'in',
#   'real',
#   'time',
#   'it',
#   'is',
#   'more',
#   'than',
#   'unencrypted',
#   'icloud',
#   'backups',
#   'more',
#   'on',
#   'this',
#   'soon…'],
#  ['end',
#   'of',
#   'thread',
#   'if',
#   'you',
#   'enjoyed',
#   'this',
#   'story',
#   'make',
#   'sure',
#   'to',
#   'rt',
#   'and',
#   'follow',
#   'mbitpodcast',
#   'lets',
#   'see',
#   'if',
#   'we',
#   'can',
#   'get',
#   'this',
#   'in',
#   'the',
#   'hands',
#   'of',
#   'ericsyuan',
#   '🚀',
#   'cc',
#   'zoom',
#   'webex',
#   'cisco',
#   'microsoft',
#   'apple',
#   'emergencecap',
#   'yahoobusiness',
#   'business'],
#  ['kyzef',
#   'justape',
#   'crazycatznft',
#   'midnightpanthrs',
#   'cyberdoodlekids',
#   'poyonft',
#   'cayalaxd',
#   'apple'],
#  ['thank',
#   'you',
#   'apple',
#   'for',
#   'land',
#   'grabbing',
#   'port',
#   'and',
#   'breaking',
#   'my',
#   'docker',
#   'compose',
#   'scripts',
#   'really',
#   'love',
#   'spending',
#   'a',
#   'few',
#   'hours',
#   'wondering',
#   'why',
#   'what',
#   'worked',
#   'yesterday',
#   'doesnt',
#   'work',
#   'today'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['apple',
#   'might',
#   'need',
#   'to',
#   'call',
#   'for',
#   'a',
#   'tutorial',
#   'on',
#   'that',
#   'laterbout',
#   'to',
#   'lose',
#   'my',
#   'damn',
#   'mind'],
#  ['guys',
#   'i',
#   'have',
#   'a',
#   'question',
#   'if',
#   'apple',
#   'states',
#   'that',
#   'the',
#   'reason',
#   'why',
#   'they',
#   'are',
#   'not',
#   'including',
#   'any',
#   'charging',
#   'bricks',
#   'on',
#   'their',
#   'iphones',
#   'but',
#   'for',
#   'ipads',
#   'they',
#   'are',
#   'including',
#   'one',
#   'just',
#   'because',
#   'its',
#   'so',
#   'expensive',
#   'so',
#   'where',
#   'is',
#   'saving',
#   'the',
#   'environment',
#   'in',
#   'that',
#   'anyone',
#   'thank',
#   'you'],
#  ['apple',
#   'is',
#   'also',
#   'happy',
#   'to',
#   'give',
#   'access',
#   'to',
#   'your',
#   'accounts',
#   'for',
#   'years',
#   'i',
#   'can',
#   'prove',
#   'for',
#   'example',
#   'that',
#   'as',
#   'you',
#   'are',
#   'typing',
#   'into',
#   'the',
#   'notes',
#   'app',
#   'pages',
#   'app',
#   'and',
#   'many',
#   'others',
#   'that',
#   'the',
#   'govt',
#   'can',
#   'watch',
#   'you',
#   'as',
#   'you',
#   'do',
#   'it',
#   'in',
#   'real',
#   'time',
#   'it',
#   'is',
#   'more',
#   'than',
#   'unencrypted',
#   'icloud',
#   'backups',
#   'more',
#   'on',
#   'this',
#   'soon…'],
#  ['end',
#   'of',
#   'thread',
#   'if',
#   'you',
#   'enjoyed',
#   'this',
#   'story',
#   'make',
#   'sure',
#   'to',
#   'rt',
#   'and',
#   'follow',
#   'mbitpodcast',
#   'lets',
#   'see',
#   'if',
#   'we',
#   'can',
#   'get',
#   'this',
#   'in',
#   'the',
#   'hands',
#   'of',
#   'ericsyuan',
#   '🚀',
#   'cc',
#   'zoom',
#   'webex',
#   'cisco',
#   'microsoft',
#   'apple',
#   'emergencecap',
#   'yahoobusiness',
#   'business'],
#  ['kyzef',
#   'justape',
#   'crazycatznft',
#   'midnightpanthrs',
#   'cyberdoodlekids',
#   'poyonft',
#   'cayalaxd',
#   'apple'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['apple',
#   'might',
#   'need',
#   'to',
#   'call',
#   'for',
#   'a',
#   'tutorial',
#   'on',
#   'that',
#   'laterbout',
#   'to',
#   'lose',
#   'my',
#   'damn',
#   'mind'],
#  ['guys',
#   'i',
#   'have',
#   'a',
#   'question',
#   'if',
#   'apple',
#   'states',
#   'that',
#   'the',
#   'reason',
#   'why',
#   'they',
#   'are',
#   'not',
#   'including',
#   'any',
#   'charging',
#   'bricks',
#   'on',
#   'their',
#   'iphones',
#   'but',
#   'for',
#   'ipads',
#   'they',
#   'are',
#   'including',
#   'one',
#   'just',
#   'because',
#   'its',
#   'so',
#   'expensive',
#   'so',
#   'where',
#   'is',
#   'saving',
#   'the',
#   'environment',
#   'in',
#   'that',
#   'anyone',
#   'thank',
#   'you'],
#  ['apple',
#   'is',
#   'also',
#   'happy',
#   'to',
#   'give',
#   'access',
#   'to',
#   'your',
#   'accounts',
#   'for',
#   'years',
#   'i',
#   'can',
#   'prove',
#   'for',
#   'example',
#   'that',
#   'as',
#   'you',
#   'are',
#   'typing',
#   'into',
#   'the',
#   'notes',
#   'app',
#   'pages',
#   'app',
#   'and',
#   'many',
#   'others',
#   'that',
#   'the',
#   'govt',
#   'can',
#   'watch',
#   'you',
#   'as',
#   'you',
#   'do',
#   'it',
#   'in',
#   'real',
#   'time',
#   'it',
#   'is',
#   'more',
#   'than',
#   'unencrypted',
#   'icloud',
#   'backups',
#   'more',
#   'on',
#   'this',
#   'soon…'],
#  ['end',
#   'of',
#   'thread',
#   'if',
#   'you',
#   'enjoyed',
#   'this',
#   'story',
#   'make',
#   'sure',
#   'to',
#   'rt',
#   'and',
#   'follow',
#   'mbitpodcast',
#   'lets',
#   'see',
#   'if',
#   'we',
#   'can',
#   'get',
#   'this',
#   'in',
#   'the',
#   'hands',
#   'of',
#   'ericsyuan',
#   '🚀',
#   'cc',
#   'zoom',
#   'webex',
#   'cisco',
#   'microsoft',
#   'apple',
#   'emergencecap',
#   'yahoobusiness',
#   'business'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['apple',
#   'might',
#   'need',
#   'to',
#   'call',
#   'for',
#   'a',
#   'tutorial',
#   'on',
#   'that',
#   'laterbout',
#   'to',
#   'lose',
#   'my',
#   'damn',
#   'mind'],
#  ['guys',
#   'i',
#   'have',
#   'a',
#   'question',
#   'if',
#   'apple',
#   'states',
#   'that',
#   'the',
#   'reason',
#   'why',
#   'they',
#   'are',
#   'not',
#   'including',
#   'any',
#   'charging',
#   'bricks',
#   'on',
#   'their',
#   'iphones',
#   'but',
#   'for',
#   'ipads',
#   'they',
#   'are',
#   'including',
#   'one',
#   'just',
#   'because',
#   'its',
#   'so',
#   'expensive',
#   'so',
#   'where',
#   'is',
#   'saving',
#   'the',
#   'environment',
#   'in',
#   'that',
#   'anyone',
#   'thank',
#   'you'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['apple',
#   'might',
#   'need',
#   'to',
#   'call',
#   'for',
#   'a',
#   'tutorial',
#   'on',
#   'that',
#   'laterbout',
#   'to',
#   'lose',
#   'my',
#   'damn',
#   'mind'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['no',
#   'there',
#   'is',
#   'nothing',
#   'you',
#   'can',
#   'immutably',
#   'claim',
#   'at',
#   'apple',
#   'you',
#   'are',
#   'permanently',
#   'at',
#   'the',
#   'visitor',
#   'center',
#   'nothing',
#   'else',
#   'johnny',
#   'ives',
#   'told',
#   'you',
#   'you',
#   'have',
#   'your',
#   'prostitute',
#   'you',
#   'are',
#   'immutably',
#   'done',
#   'thanks'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['plastikbidon', 'apple', 'ne', 'alaka'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['plastikbidon', 'apple', 'ne', 'alaka'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['plastikbidon', 'apple', 'ne', 'alaka'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['plastikbidon', 'apple', 'ne', 'alaka'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'pricey', 'thats', 'iphone'],
#  ['plastikbidon', 'apple', 'ne', 'alaka'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'i', 'so', 'need', 'this', '📱'],
#  ['plastikbidon', 'apple', 'ne', 'alaka'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['and',
#   'this',
#   'is',
#   'why',
#   'i',
#   'love',
#   'iphone',
#   'read',
#   'it',
#   'amp',
#   'i',
#   'bet',
#   'you',
#   'feel',
#   'so',
#   'much',
#   'secured',
#   'in',
#   'this',
#   'planet',
#   'apple'],
#  ['apple', 'i', 'so', 'need', 'this', '📱'],
#  ['plastikbidon', 'apple', 'ne', 'alaka'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['apple',
#   'پول',
#   'خریدنتو',
#   'نداریم',
#   '،کم',
#   'تبلیغ',
#   'کن',
#   'خب',
#   'هی',
#   'دل',
#   'ما',
#   'رو',
#   'بسوزون😒',
#   'با',
#   'این',
#   'بی',
#   'ارزش',
#   'بودن',
#   'پولمون',
#   'تا',
#   'صد',
#   'سال',
#   'دیگه',
#   'هم',
#   'نمی\u200cتونیم',
#   'بخریم'],
#  ['apple', 'i', 'so', 'need', 'this', '📱'],
#  ['plastikbidon', 'apple', 'ne', 'alaka'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['apple',
#   'final',
#   'cut',
#   'has',
#   'been',
#   'crashing',
#   'multiple',
#   'times',
#   'a',
#   'day',
#   'more',
#   'than',
#   'adobe',
#   'premiere',
#   'pro',
#   'lately',
#   '🤦🏽\u200d♂️'],
#  ['apple', 'i', 'feel', 'the', 'same'],
#  ['apple',
#   'پول',
#   'خریدنتو',
#   'نداریم',
#   '،کم',
#   'تبلیغ',
#   'کن',
#   'خب',
#   'هی',
#   'دل',
#   'ما',
#   'رو',
#   'بسوزون😒',
#   'با',
#   'این',
#   'بی',
#   'ارزش',
#   'بودن',
#   'پولمون',
#   'تا',
#   'صد',
#   'سال',
#   'دیگه',
#   'هم',
#   'نمی\u200cتونیم',
#   'بخریم'],
#  ['apple', 'i', 'so', 'need', 'this', '📱'],
#  ['plastikbidon', 'apple', 'ne', 'alaka'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['apple', 'and', 'you', 'think', 'this', 'is', 'a', 'good', 'offer', '😂'],
#  ['elonmusk', 'you', 'must', 'have', 'got', 'this', 'isn’t', 'apple'],
#  ['new',
#   'ep',
#   'ep',
#   'airbnbs',
#   'hiroki',
#   'asai',
#   'on',
#   'designing',
#   'environments',
#   'for',
#   'creative',
#   'teams',
#   'to',
#   'thrive',
#   '\u2060✨',
#   'hiroki',
#   'chats',
#   'w',
#   'amydevers',
#   'about',
#   'riding',
#   'his',
#   'bmx',
#   'through',
#   'the',
#   'orchards',
#   'of',
#   'cupertino',
#   'taking',
#   'night',
#   'school',
#   'art',
#   'classes',
#   'as',
#   'a',
#   'teen',
#   'working',
#   'at',
#   'apple',
#   'listen',
#   'at'],
#  ['apple',
#   'پول',
#   'خریدنتو',
#   'نداریم',
#   '،کم',
#   'تبلیغ',
#   'کن',
#   'خب',
#   'هی',
#   'دل',
#   'ما',
#   'رو',
#   'بسوزون😒',
#   'با',
#   'این',
#   'بی',
#   'ارزش',
#   'بودن',
#   'پولمون',
#   'تا',
#   'صد',
#   'سال',
#   'دیگه',
#   'هم',
#   'نمی\u200cتونیم',
#   'بخریم'],
#  ['apple', 'i', 'so', 'need', 'this', '📱'],
#  ['plastikbidon', 'apple', 'ne', 'alaka'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['royabbink', 'apple', 'ty'],
#  ['elonmusk', 'you', 'must', 'have', 'got', 'this', 'isn’t', 'apple'],
#  ['new',
#   'ep',
#   'ep',
#   'airbnbs',
#   'hiroki',
#   'asai',
#   'on',
#   'designing',
#   'environments',
#   'for',
#   'creative',
#   'teams',
#   'to',
#   'thrive',
#   '\u2060✨',
#   'hiroki',
#   'chats',
#   'w',
#   'amydevers',
#   'about',
#   'riding',
#   'his',
#   'bmx',
#   'through',
#   'the',
#   'orchards',
#   'of',
#   'cupertino',
#   'taking',
#   'night',
#   'school',
#   'art',
#   'classes',
#   'as',
#   'a',
#   'teen',
#   'working',
#   'at',
#   'apple',
#   'listen',
#   'at'],
#  ['apple',
#   'پول',
#   'خریدنتو',
#   'نداریم',
#   '،کم',
#   'تبلیغ',
#   'کن',
#   'خب',
#   'هی',
#   'دل',
#   'ما',
#   'رو',
#   'بسوزون😒',
#   'با',
#   'این',
#   'بی',
#   'ارزش',
#   'بودن',
#   'پولمون',
#   'تا',
#   'صد',
#   'سال',
#   'دیگه',
#   'هم',
#   'نمی\u200cتونیم',
#   'بخریم'],
#  ['apple', 'i', 'so', 'need', 'this', '📱'],
#  ['plastikbidon', 'apple', 'ne', 'alaka'],
#  ['i', 'knew', 'my', 'shit', 'was', 'tapped', 'ya', 'done', 'apple'],
#  ['johny',
#   'ives',
#   'told',
#   'you',
#   'at',
#   'apple',
#   'you',
#   'had',
#   'your',
#   'check',
#   'of',
#   'war',
#   'you',
#   'are',
#   'immutably',
#   'forever',
#   'done'],
#  ['elonmusk',
#   'nicolescherzy',
#   'shwetabhj',
#   'kanyewest',
#   'apple',
#   'applemusic',
#   'appletv',
#   'xxccyyman',
#   'mattgaetz',
#   'realandyleeshow',
#   'pierrepoilievre',
#   'donaldjtrumpjr',
#   'jackposobiec',
#   'wake',
#   'up',
#   'pray',
#   'up',
#   '🙏💯❤️\u200d🔥🌹\U0001fac2💋😍🔜♾️🔂',
#   'gellertdepp',
#   '👑🔥'],
#  ['hi',
#   'apple',
#   'can',
#   'we',
#   'get',
#   'a',
#   'nosebleed',
#   'emoji',
#   'on',
#   'the',
#   'next',
#   'update'],
#  ['royabbink', 'apple', 'ty'],
#  ['elonmusk', 'you', 'must', 'have', 'got', 'this', 'isn’t', 'apple'],
#  ['new',
#   'ep',
#   'ep',
#   'airbnbs',
#   'hiroki',
#   'asai',
#   'on',
#   'designing',
#   'environments',
#   'for',
#   'creative',
#   'teams',
#   'to',
#   'thrive',
#   '\u2060✨',
#   'hiroki',
#   'chats',
#   'w',
#   'amydevers',
#   'about',
#   'riding',
#   'his',
#   'bmx',
#   'through',
#   'the',
#   'orchards',
#   'of',
#   'cupertino',
#   'taking',
#   'night',
#   'school',
#   'art',
#   'classes',
#   'as',
#   'a',
#   'teen',
#   'working',
#   'at',
#   'apple',
#   'listen',
#   'at'],
#  ['apple',
#   'پول',
#   'خریدنتو',
#   'نداریم',
#   '،کم',
#   'تبلیغ',
#   'کن',
#   'خب',
#   'هی',
#   'دل',
#   'ما',
#   'رو',
#   'بسوزون😒',
#   'با',
#   'این',
#   'بی',
#   'ارزش',
#   'بودن',
#   'پولمون',
#   'تا',
# ...
#   'and',
#   'carplay',
#   'laptop',
#   'and',
#   'ipad',
#   'are',
#   'okay',
#   'though'],
#  ['lapple',
#   'apple',
#   'watch',
#   'reste',
#   'indélogeable',
#   'de',
#   'sa',
#   'première',
#   'place',
#   '🌍'],
#  ['apple', 'i', '❤️🍎'],
#  ['why',
#   'does',
#   'my',
#   'iphone',
#   'always',
#   'connects',
#   'to',
#   'the',
#   'weaker',
#   'wifi',
#   'network',
#   'availableis',
#   'there',
#   'some',
#   'setting',
#   'for',
#   'choosing',
#   'the',
#   'stronger',
#   'network',
#   'cause',
#   'i',
#   'refuse',
#   'to',
#   'believe',
#   'that',
#   'such',
#   'an',
#   'essential',
#   'feature',
#   'is',
#   'missing',
#   'from',
#   'apple',
#   'ps',
#   'all',
#   'networks',
#   'are',
#   'saved',
#   'in',
#   'the',
#   'phone'],
#  ['timcook', 'apple', '🤣🤣🤣'],
#  ['judiciarygop',
#   'this',
#   'country',
#   'is',
#   'bathing',
#   'in',
#   'guns',
#   'and',
#   'you',
#   'cowards',
#   'sit',
#   'here',
#   'and',
#   'play',
#   'politics',
#   'truly',
#   'shameful',
#   'i',
#   'know',
#   'we',
#   'will',
#   'only',
#   'see',
#   'change',
#   'if',
#   'big',
#   'money',
#   'corporations',
#   'start',
#   'speaking',
#   'out',
#   'because',
#   'you',
#   'all',
#   'sure',
#   'do',
#   'not',
#   'have',
#   'a',
#   'spine',
#   'nike',
#   'tesla',
#   'apple',
#   'google',
#   'visa',
#   'mastercard',
#   'disneyparks',
#   'oracle'],
#  ['why',
#   'doesn’t',
#   'the',
#   'iphone',
#   'autocorrect',
#   '“constipated”',
#   'does',
#   'apple',
#   'not',
#   'want',
#   'anyone',
#   'to',
#   'talk',
#   'about',
#   'bowel',
#   'movements',
#   'i',
#   'have',
#   'pondered',
#   'this',
#   'for',
#   'years…',
#   '🧐'],
#  ['mikeymanziel',
#   'apple',
#   'mines',
#   'been',
#   'buggy',
#   'all',
#   'week',
#   'apple',
#   'definitely',
#   'doin',
#   'sim',
#   'shit'],
#  ['як',
#   'вирішити',
#   'цю',
#   'проблему',
#   'я',
#   'не',
#   'знаю',
#   'англійської',
#   'як',
#   'мені',
#   'користуватися',
#   'вашими',
#   'продуктами',
#   'якщо',
#   'ви',
#   'не',
#   'можете',
#   'додати',
#   'українську',
#   'мову',
#   'це',
#   'так',
#   'важко',
#   'вам',
#   'допомогти',
#   'з',
#   'перекладом',
#   'вам',
#   'вся',
#   'україна',
#   'допоможе',
#   'apple',
#   'applesupport',
#   'microsoft'],
#  ['apple',
#   'vous',
#   'vous',
#   'etes',
#   'pas',
#   'fait',
#   'condamner',
#   'pcq',
#   'vous',
#   'gardiezrevendez',
#   'les',
#   'données',
#   'ou',
#   'un',
#   'truc',
#   'du',
#   'genre'],
#  ['nevslin',
#   'apple',
#   'this',
#   'update',
#   'messes',
#   'up',
#   'apple',
#   'watches',
#   'and',
#   'carplay',
#   'laptop',
#   'and',
#   'ipad',
#   'are',
#   'okay',
#   'though'],
#  ['lapple',
#   'apple',
#   'watch',
#   'reste',
#   'indélogeable',
#   'de',
#   'sa',
#   'première',
#   'place',
#   '🌍'],
#  ['apple', 'i', '❤️🍎'],
#  ['apple', 'needs', 'to', 'buy', 'mullenusa', 'now', 'tesla'],
#  ['timcook', 'apple', '🤣🤣🤣'],
#  ['judiciarygop',
#   'this',
#   'country',
#   'is',
#   'bathing',
#   'in',
#   'guns',
#   'and',
#   'you',
#   'cowards',
#   'sit',
#   'here',
#   'and',
#   'play',
#   'politics',
#   'truly',
#   'shameful',
#   'i',
#   'know',
#   'we',
#   'will',
#   'only',
#   'see',
#   'change',
#   'if',
#   'big',
#   'money',
#   'corporations',
#   'start',
#   'speaking',
#   'out',
#   'because',
#   'you',
#   'all',
#   'sure',
#   'do',
#   'not',
#   'have',
#   'a',
#   'spine',
#   'nike',
#   'tesla',
#   'apple',
#   'google',
#   'visa',
#   'mastercard',
#   'disneyparks',
#   'oracle'],
#  ['why',
#   'doesn’t',
#   'the',
#   'iphone',
#   'autocorrect',
#   '“constipated”',
#   'does',
#   'apple',
#   'not',
#   'want',
#   'anyone',
#   'to',
#   'talk',
#   'about',
#   'bowel',
#   'movements',
#   'i',
#   'have',
#   'pondered',
#   'this',
#   'for',
#   'years…',
#   '🧐'],
#  ['mikeymanziel',
#   'apple',
#   'mines',
#   'been',
#   'buggy',
#   'all',
#   'week',
#   'apple',
#   'definitely',
#   'doin',
#   'sim',
#   'shit'],
#  ['як',
#   'вирішити',
#   'цю',
#   'проблему',
#   'я',
#   'не',
#   'знаю',
#   'англійської',
#   'як',
#   'мені',
#   'користуватися',
#   'вашими',
#   'продуктами',
#   'якщо',
#   'ви',
#   'не',
#   'можете',
#   'додати',
#   'українську',
#   'мову',
#   'це',
#   'так',
#   'важко',
#   'вам',
#   'допомогти',
#   'з',
#   'перекладом',
#   'вам',
#   'вся',
#   'україна',
#   'допоможе',
#   'apple',
#   'applesupport',
#   'microsoft'],
#  ['apple',
#   'vous',
#   'vous',
#   'etes',
#   'pas',
#   'fait',
#   'condamner',
#   'pcq',
#   'vous',
#   'gardiezrevendez',
#   'les',
#   'données',
#   'ou',
#   'un',
#   'truc',
#   'du',
#   'genre'],
#  ['nevslin',
#   'apple',
#   'this',
#   'update',
#   'messes',
#   'up',
#   'apple',
#   'watches',
#   'and',
#   'carplay',
#   'laptop',
#   'and',
#   'ipad',
#   'are',
#   'okay',
#   'though'],
#  ['lapple',
#   'apple',
#   'watch',
#   'reste',
#   'indélogeable',
#   'de',
#   'sa',
#   'première',
#   'place',
#   '🌍'],
#  ['apple', 'i', '❤️🍎'],
#  ['apple', 'needs', 'to', 'buy', 'mullenusa', 'now', 'tesla'],
#  ['timcook', 'apple', '🤣🤣🤣'],
#  ['judiciarygop',
#   'this',
#   'country',
#   'is',
#   'bathing',
#   'in',
#   'guns',
#   'and',
#   'you',
#   'cowards',
#   'sit',
#   'here',
#   'and',
#   'play',
#   'politics',
#   'truly',
#   'shameful',
#   'i',
#   'know',
#   'we',
#   'will',
#   'only',
#   'see',
#   'change',
#   'if',
#   'big',
#   'money',
#   'corporations',
#   'start',
#   'speaking',
#   'out',
#   'because',
#   'you',
#   'all',
#   'sure',
#   'do',
#   'not',
#   'have',
#   'a',
#   'spine',
#   'nike',
#   'tesla',
#   'apple',
#   'google',
#   'visa',
#   'mastercard',
#   'disneyparks',
#   'oracle'],
#  ['why',
#   'doesn’t',
#   'the',
#   'iphone',
#   'autocorrect',
#   '“constipated”',
#   'does',
#   'apple',
#   'not',
#   'want',
#   'anyone',
#   'to',
#   'talk',
#   'about',
#   'bowel',
#   'movements',
#   'i',
#   'have',
#   'pondered',
#   'this',
#   'for',
#   'years…',
#   '🧐'],
#  ['mikeymanziel',
#   'apple',
#   'mines',
#   'been',
#   'buggy',
#   'all',
#   'week',
#   'apple',
#   'definitely',
#   'doin',
#   'sim',
#   'shit'],
#  ['як',
#   'вирішити',
#   'цю',
#   'проблему',
#   'я',
#   'не',
#   'знаю',
#   'англійської',
#   'як',
#   'мені',
#   'користуватися',
#   'вашими',
#   'продуктами',
#   'якщо',
#   'ви',
#   'не',
#   'можете',
#   'додати',
#   'українську',
#   'мову',
#   'це',
#   'так',
#   'важко',
#   'вам',
#   'допомогти',
#   'з',
#   'перекладом',
#   'вам',
#   'вся',
#   'україна',
#   'допоможе',
#   'apple',
#   'applesupport',
#   'microsoft'],
#  ['apple',
#   'vous',
#   'vous',
#   'etes',
#   'pas',
#   'fait',
#   'condamner',
#   'pcq',
#   'vous',
#   'gardiezrevendez',
#   'les',
#   'données',
#   'ou',
#   'un',
#   'truc',
#   'du',
#   'genre'],
#  ['nevslin',
#   'apple',
#   'this',
#   'update',
#   'messes',
#   'up',
#   'apple',
#   'watches',
#   'and',
#   'carplay',
#   'laptop',
#   'and',
#   'ipad',
#   'are',
#   'okay',
#   'though'],
#  ['apple',
#   'i',
#   'can’t',
#   'update',
#   'account',
#   'info',
#   'as',
#   'it’s',
#   'telling',
#   'me',
#   'i',
#   'have',
#   'to',
#   'give',
#   'a',
#   'title',
#   'but',
#   'it’s',
#   'not',
#   'got',
#   'ms',
#   'or',
#   'miss',
#   'only',
#   'mr',
#   'mrs',
#   'dr',
#   'amp',
#   'not',
#   'specified',
#   'which',
#   'the',
#   'latter',
#   'it',
#   'won’t',
#   'let',
#   'me',
#   'choose',
#   'also',
#   'needs',
#   'non',
#   'binary',
#   'titles',
#   'adding'],
#  ['diastema',
#   'ain’t',
#   'no',
#   'disability',
#   'applesupport',
#   'apple',
#   'where’s',
#   'my',
#   'smiley',
#   'applenews'],
#  ['apple', 'needs', 'to', 'buy', 'mullenusa', 'now', 'tesla'],
#  ['timcook', 'apple', '🤣🤣🤣'],
#  ['judiciarygop',
#   'this',
#   'country',
#   'is',
#   'bathing',
#   'in',
#   'guns',
#   'and',
#   'you',
#   'cowards',
#   'sit',
#   'here',
#   'and',
#   'play',
#   'politics',
#   'truly',
#   'shameful',
#   'i',
#   'know',
#   'we',
#   'will',
#   'only',
#   'see',
#   'change',
#   'if',
#   'big',
#   'money',
#   'corporations',
#   'start',
#   'speaking',
#   'out',
#   'because',
#   'you',
#   'all',
#   'sure',
#   'do',
#   'not',
#   'have',
#   'a',
#   'spine',
#   'nike',
#   'tesla',
#   'apple',
#   'google',
#   'visa',
#   'mastercard',
#   'disneyparks',
#   'oracle'],
#  ['why',
#   'doesn’t',
#   'the',
#   'iphone',
#   'autocorrect',
#   '“constipated”',
#   'does',
#   'apple',
#   'not',
#   'want',
#   'anyone',
#   'to',
#   'talk',
#   'about',
#   'bowel',
#   'movements',
#   'i',
#   'have',
#   'pondered',
#   'this',
#   'for',
#   'years…',
#   '🧐'],
#  ['mikeymanziel',
#   'apple',
#   'mines',
#   'been',
#   'buggy',
#   'all',
#   'week',
#   'apple',
#   'definitely',
#   'doin',
#   'sim',
#   'shit'],
#  ['як',
#   'вирішити',
#   'цю',
#   'проблему',
#   'я',
#   'не',
#   'знаю',
#   'англійської',
#   'як',
#   'мені',
#   'користуватися',
#   'вашими',
#   'продуктами',
#   'якщо',
#   'ви',
#   'не',
#   'можете',
#   'додати',
#   'українську',
#   'мову',
#   'це',
#   'так',
#   'важко',
#   'вам',
#   'допомогти',
#   'з',
#   'перекладом',
#   'вам',
#   'вся',
#   'україна',
#   'допоможе',
#   'apple',
#   'applesupport',
#   'microsoft'],
#  ['apple',
#   'vous',
#   'vous',
#   'etes',
#   'pas',
#   'fait',
#   'condamner',
#   'pcq',
#   'vous',
#   'gardiezrevendez',
#   'les',
#   'données',
#   'ou',
#   'un',
#   'truc',
#   'du',
#   'genre'],
#  ['apple',
#   'applesupport',
#   'microsoft',
#   'apple',
#   'it',
#   'seems',
#   'like',
#   'this',
#   'is',
#   'something',
#   'you',
#   'should',
#   'prioritize',
#   'especially',
#   'now'],
#  ['apple',
#   'i',
#   'can’t',
#   'update',
#   'account',
#   'info',
#   'as',
#   'it’s',
#   'telling',
#   'me',
#   'i',
#   'have',
#   'to',
#   'give',
#   'a',
#   'title',
#   'but',
#   'it’s',
#   'not',
#   'got',
#   'ms',
#   'or',
#   'miss',
#   'only',
#   'mr',
#   'mrs',
#   'dr',
#   'amp',
#   'not',
#   'specified',
#   'which',
#   'the',
#   'latter',
#   'it',
#   'won’t',
#   'let',
#   'me',
#   'choose',
#   'also',
#   'needs',
#   'non',
#   'binary',
#   'titles',
#   'adding'],
#  ['diastema',
#   'ain’t',
#   'no',
#   'disability',
#   'applesupport',
#   'apple',
#   'where’s',
#   'my',
#   'smiley',
#   'applenews'],
#  ['apple', 'needs', 'to', 'buy', 'mullenusa', 'now', 'tesla'],
#  ['timcook', 'apple', '🤣🤣🤣'],
#  ['judiciarygop',
#   'this',
#   'country',
#   'is',
#   'bathing',
#   'in',
#   'guns',
#   'and',
#   'you',
#   'cowards',
#   'sit',
#   'here',
#   'and',
#   'play',
#   'politics',
#   'truly',
#   'shameful',
#   'i',
#   'know',
#   'we',
#   'will',
#   'only',
#   'see',
#   'change',
#   'if',
#   'big',
#   'money',
#   'corporations',
#   'start',
#   'speaking',
#   'out',
#   'because',
#   'you',
#   'all',
#   'sure',
#   'do',
#   'not',
#   'have',
#   'a',
#   'spine',
#   'nike',
#   'tesla',
#   'apple',
#   'google',
#   'visa',
#   'mastercard',
#   'disneyparks',
#   'oracle'],
#  ['why',
#   'doesn’t',
#   'the',
#   'iphone',
#   'autocorrect',
#   '“constipated”',
#   'does',
#   'apple',
#   'not',
#   'want',
#   'anyone',
#   'to',
#   'talk',
#   'about',
#   'bowel',
#   'movements',
#   'i',
#   'have',
#   'pondered',
#   'this',
#   'for',
#   'years…',
#   '🧐'],
#  ['mikeymanziel',
#   'apple',
#   'mines',
#   'been',
#   'buggy',
#   'all',
#   'week',
#   'apple',
#   'definitely',
#   'doin',
#   'sim',
#   'shit'],
#  ['як',
#   'вирішити',
#   'цю',
#   'проблему',
#   'я',
#   'не',
#   'знаю',
#   'англійської',
#   'як',
#   'мені',
#   'користуватися',
#   'вашими',
#   'продуктами',
#   'якщо',
#   'ви',
#   'не',
#   'можете',
#   'додати',
#   'українську',
#   'мову',
#   'це',
#   'так',
#   'важко',
#   'вам',
#   'допомогти',
#   'з',
#   'перекладом',
#   'вам',
#   'вся',
#   'україна',
#   'допоможе',
#   'apple',
#   'applesupport',
#   'microsoft'],
#  ['apple',
#   'vous',
#   'vous',
#   'etes',
#   'pas',
#   'fait',
#   'condamner',
#   'pcq',
#   'vous',
#   'gardiezrevendez',
#   'les',
#   'données',
#   'ou',
#   'un',
#   'truc',
#   'du',
#   'genre'],
#  ['apple',
#   'applesupport',
#   'microsoft',
#   'apple',
#   'it',
#   'seems',
#   'like',
#   'this',
#   'is',
#   'something',
#   'you',
#   'should',
#   'prioritize',
#   'especially',
#   'now'],
#  ['apple',
#   'i',
#   'can’t',
#   'update',
#   'account',
#   'info',
#   'as',
#   'it’s',
#   'telling',
#   'me',
#   'i',
#   'have',
#   'to',
#   'give',
#   'a',
#   'title',
#   'but',
#   'it’s',
#   'not',
#   'got',
#   'ms',
#   'or',
#   'miss',
#   'only',
#   'mr',
#   'mrs',
#   'dr',
#   'amp',
#   'not',
#   'specified',
#   'which',
#   'the',
#   'latter',
#   'it',
#   'won’t',
#   'let',
#   'me',
#   'choose',
#   'also',
#   'needs',
#   'non',
#   'binary',
#   'titles',
#   'adding'],
#  ['diastema',
#   'ain’t',
#   'no',
#   'disability',
#   'applesupport',
#   'apple',
#   'where’s',
#   'my',
#   'smiley',
#   'applenews'],
#  ['apple', 'needs', 'to', 'buy', 'mullenusa', 'now', 'tesla'],
#  ['timcook', 'apple', '🤣🤣🤣'],
#  ['judiciarygop',
#   'this',
#   'country',
#   'is',
#   'bathing',
#   'in',
#   'guns',
#   'and',
#   'you',
#   'cowards',
#   'sit',
#   'here',
#   'and',
#   'play',
#   'politics',
#   'truly',
#   'shameful',
#   'i',
#   'know',
#   'we',
#   'will',
#   'only',
#   'see',
#   'change',
#   'if',
#   'big',
#   'money',
#   'corporations',
#   'start',
#   'speaking',
#   'out',
#   'because',
#   'you',
#   'all',
#   'sure',
#   'do',
#   'not',
#   'have',
#   'a',
#   'spine',
#   'nike',
#   'tesla',
#   'apple',
#   'google',
#   'visa',
#   'mastercard',
#   'disneyparks',
#   'oracle'],
#  ['why',
#   'doesn’t',
#   'the',
#   'iphone',
#   'autocorrect',
#   '“constipated”',
#   'does',
#   'apple',
#   'not',
#   'want',
#   'anyone',
#   'to',
#   'talk',
#   'about',
#   'bowel',
#   'movements',
#   'i',
#   'have',
#   'pondered',
#   'this',
#   'for',
#   'years…',
#   '🧐'],
#  ['mikeymanziel',
#   'apple',
#   'mines',
#   'been',
#   'buggy',
#   'all',
#   'week',
#   'apple',
#   'definitely',
#   'doin',
#   'sim',
#   'shit'],
#  ['як',
#   'вирішити',
#   'цю',
#   'проблему',
#   'я',
#   'не',
#   'знаю',
#   'англійської',
#   'як',
#   'мені',
#   'користуватися',
#   'вашими',
#   'продуктами',
#   'якщо',
#   'ви',
#   'не',
#   'можете',
#   'додати',
#   'українську',
#   'мову',
#   'це',
#   'так',
#   'важко',
#   'вам',
#   'допомогти',
#   'з',
#   'перекладом',
#   'вам',
#   'вся',
#   'україна',
#   'допоможе',
#   'apple',
#   'applesupport',
#   'microsoft'],
#  ['apple',
#   'vous',
#   'vous',
#   'etes',
#   'pas',
#   'fait',
#   'condamner',
#   'pcq',
#   'vous',
#   'gardiezrevendez',
#   'les',
#   'données',
#   'ou',
#   'un',
#   'truc',
#   'du',
#   'genre'],
#  ['apple',
#   'applesupport',
#   'microsoft',
#   'apple',
#   'it',
#   'seems',
#   'like',
#   'this',
#   'is',
#   'something',
#   'you',
#   'should',
#   'prioritize',
#   'especially',
#   'now'],
#  ['apple',
#   'i',
#   'can’t',
#   'update',
#   'account',
#   'info',
#   'as',
#   'it’s',
#   'telling',
#   'me',
#   'i',
#   'have',
#   'to',
#   'give',
#   'a',
#   'title',
#   'but',
#   'it’s',
#   'not',
#   'got',
#   'ms',
#   'or',
#   'miss',
#   'only',
#   'mr',
#   'mrs',
#   'dr',
#   'amp',
#   'not',
#   'specified',
#   'which',
#   'the',
#   'latter',
#   'it',
#   'won’t',
#   'let',
#   'me',
#   'choose',
#   'also',
#   'needs',
#   'non',
#   'binary',
#   'titles',
#   'adding'],
#  ['diastema',
#   'ain’t',
#   'no',
#   'disability',
#   'applesupport',
#   'apple',
#   'where’s',
#   'my',
#   'smiley',
#   'applenews'],
#  ['apple', 'needs', 'to', 'buy', 'mullenusa', 'now', 'tesla'],
#  ['timcook', 'apple', '🤣🤣🤣'],
#  ['judiciarygop',
#   'this',
#   'country',
#   'is',
#   'bathing',
#   'in',
#   'guns',
#   'and',
#   'you',
#   'cowards',
#   'sit',
#   'here',
#   'and',
#   'play',
#   'politics',
#   'truly',
#   'shameful',
#   'i',
#   'know',
#   'we',
#   'will',
#   'only',
#   'see',
#   'change',
#   'if',
#   'big',
#   'money',
#   'corporations',
#   'start',
#   'speaking',
#   'out',
#   'because',
#   'you',
#   'all',
#   'sure',
#   'do',
#   'not',
#   'have',
#   'a',
#   'spine',
#   'nike',
#   'tesla',
#   'apple',
#   'google',
#   'visa',
#   'mastercard',
#   'disneyparks',
#   'oracle'],
#  ['why',
#   'doesn’t',
#   'the',
#   'iphone',
#   'autocorrect',
#   '“constipated”',
#   'does',
#   'apple',
#   'not',
#   'want',
#   'anyone',
#   'to',
#   'talk',
#   'about',
#   'bowel',
#   'movements',
#   'i',
#   'have',
#   'pondered',
#   'this',
#   'for',
#   'years…',
#   '🧐'],
#  ['mikeymanziel',
#   'apple',
#   'mines',
#   'been',
#   'buggy',
#   'all',
#   'week',
#   'apple',
#   'definitely',
#   'doin',
#   'sim',
#   'shit'],
#  ['як',
#   'вирішити',
#   'цю',
#   'проблему',
#   'я',
#   'не',
#   'знаю',
#   'англійської',
#   'як',
#   'мені',
#   'користуватися',
#   'вашими',
#   'продуктами',
#   'якщо',
#   'ви',
#   'не',
#   'можете',
#   'додати',
#   'українську',
#   'мову',
#   'це',
#   'так',
#   'важко',
#   'вам',
#   'допомогти',
#   'з',
#   'перекладом',
#   'вам',
#   'вся',
#   'україна',
#   'допоможе',
#   'apple',
#   'applesupport',
#   'microsoft'],
#  ['petition', 'for', 'apple', 'to', 'make', 'a', 'kashmir', 'flag', 'emoji'],
#  ['apple',
#   'applesupport',
#   'microsoft',
#   'apple',
#   'it',
#   'seems',
#   'like',
#   'this',
#   'is',
#   'something',
#   'you',
#   'should',
#   'prioritize',
#   'especially',
#   'now'],
#  ['apple',
#   'i',
#   'can’t',
#   'update',
#   'account',
#   'info',
#   'as',
#   'it’s',
#   'telling',
#   'me',
#   'i',
#   'have',
#   'to',
#   'give',
#   'a',
#   'title',
#   'but',
#   'it’s',
#   'not',
#   'got',
#   'ms',
#   'or',
#   'miss',
#   'only',
#   'mr',
#   'mrs',
#   'dr',
#   'amp',
#   'not',
#   'specified',
#   'which',
#   'the',
#   'latter',
#   'it',
#   'won’t',
#   'let',
#   'me',
#   'choose',
#   'also',
#   'needs',
#   'non',
#   'binary',
#   'titles',
#   'adding'],
#  ['diastema',
#   'ain’t',
#   'no',
#   'disability',
#   'applesupport',
#   'apple',
#   'where’s',
#   'my',
#   'smiley',
#   'applenews'],
#  ['apple', 'needs', 'to', 'buy', 'mullenusa', 'now', 'tesla'],
#  ['timcook', 'apple', '🤣🤣🤣'],
#  ...]

# %%
ls_train[0]
# Out:
# 'no there is nothing you can immutably claim at apple you are permanently at the visitor center nothing else johnny ives told you you have your  prostitute you are immutably done thanks'
