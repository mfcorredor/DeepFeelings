# %%
import string 
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import pandas as pd
import re
import numpy as np
import emoji


def remove_emoji(string):
    return emoji.get_emoji_regexp().sub(u'', string)

def clean_text(text):
    
    text = str(text).lower() #Make text lowercase
    text = re.sub('\[.*?\]', '', text) #remove text in square brackets
    text = re.sub('https?://\S+|www\.\S+', '', text) #,remove links
    text = re.sub('<.*?>+', '', text) #remove punctuation
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text) #remove punctuation
    text = re.sub('\n', '', text) #containing numbers
    text = re.sub('\w*\d\w*', '', text) #remove numbers
    text = ''.join([i for i in text if not i.isdigit()]) #remove numbers
    
    return text
    
def preprocessing(text, list_format = True):
    text = clean_text(text)
    text = remove_emoji(text)
    if list_format:
        text = text.split(" ")
    return text

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       2 from selenium import webdriver
#       3 import pandas as pd
# ----> 4 from amzwbscr_selenium import scrape_amz
#
# ModuleNotFoundError: No module named 'amzwbscr_selenium'

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd


# using the product ID to create url
def scrape_amz(product_id):

    #start webdriver
    driver = webdriver.Chrome("/Users/jannick/Downloads/chromedriver")

    #defining the url for the first page
    page_no = 1
    url = f"https://www.amazon.com/en/product-reviews/{product_id}/ref=cm_cr_dp_d_paging_btm_next_{page_no}?ie=UTF8&reviewerType=all_reviews&pageNumber={page_no}"

    #create the lists for the data
    reviews = []
    review_metas = []

    pages = 5

    #counting no of pages, can be used for pages
    #driver.get(url)
    #soup = BeautifulSoup(driver.page_source, "html.parser")
    #review_count = soup.find("div", class_= "a-row a-spacing-base a-size-base").text
    #review_no = review_count.replace("\n", "").replace(" ","").replace(",","")
    #max_len_rno = min([13, len(review_no)])
    #review_no = review_no[:-max_len_rno].split("|")[1]
    #review_no = float(review_no)
    #pages_counted = round(review_no/10) -1
    #print(f"total pages would be {pages_counted} but we only look at {pages}")


    #go to every page
    for i in range(1, pages+1):

        #get the soup of each page
        driver.get(url)
        soup = BeautifulSoup(driver.page_source, "html.parser")
        review_parent = soup.find_all("div", class_ = "a-row a-spacing-small review-data")

        #get each review text
        for i in review_parent:
            #review = review_parent.find("span", class_ = "cr-original-review-content")
            reviews.append(i.text.replace("\n",""))

        #get each review meta
        review_meta = soup.find_all("span",
                                   {"data-hook":True},
                                   class_="a-size-base a-color-secondary review-date")
        for i in review_meta:
            helper = i.text[12:]
            review_metas.append(helper.split(" on "))

        print(f"page {page_no} of {pages} scraped")

        #update url for next page
        page_no += 1
        url = f"https://www.amazon.com/product-reviews/{product_id}/ref=cm_cr_dp_d_paging_btm_next_{page_no}?ie=UTF8&reviewerType=all_reviews&pageNumber={page_no}"


    #create df
    metas_df = pd.DataFrame(review_metas)
    metas_df[1] = pd.to_datetime(metas_df[1])
    texts_df = pd.DataFrame(reviews)
    df = pd.DataFrame()
    #df["country"] = metas_df[0]
    df["date"] = metas_df[1]
    df["text"] = texts_df

    return df

# %%
df = scrape_amz("B08BGD4G36")
# Out:
# /var/folders/s4/671kyfms3wnc45z745cx9dc00000gn/T/ipykernel_35988/2815067336.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/Users/jannick/Downloads/chromedriver")
# page 1 of 5 scraped
# page 2 of 5 scraped
# page 3 of 5 scraped
# page 4 of 5 scraped
# page 5 of 5 scraped

# %%
df
# Out:
#          date                                               text
# 0  2019-04-27  I was a little sceptical buying this phone bec...
# 1  2019-06-12  This seller is amazing was a bit skeptical at ...
# 2  2019-08-20  Just was told by my carrier, ATT, that this ph...
# 3  2019-05-14  I purchased this phone for my daughter and it ...
# 4  2019-05-21  I don’t know why everyone’s giving this seller...
# 5  2019-06-10                      The media could not be loa...
# 6  2019-05-21  Received my IPhone a few days ago and everythi...
# 7  2019-04-03  i absolutly LOVED this IPhone XR it was wonder...
# 8  2019-08-15  I’ll admit after reading through the reviews I...
# 9  2019-08-14  Update: 04/06/2021: I still have this phone. S...
# 10 2019-07-03  I purchased this red xr about 3 weeks ago i fi...
# 11 2019-06-10  Back was cracked in several places. Screen sev...
# 12 2019-05-09  It took a little while for it to arrive. But o...
# 13 2019-07-27  PLEASE DO NOT BUY THIS PHONE. They say that th...
# 14 2019-05-31  I love how it was super intact on the outside ...
# 15 2019-05-18  Pésimo el teléfono vino bloqueado con clave y ...
# 16 2019-05-20  World's worst thing ever never get on this its...
# 17 2019-07-09  Phone looks literally brand new no cracks work...
# 18 2019-04-12  Described as “fully unlocked”. Received it in ...
# 19 2020-03-05  Just what I needed for my teenager, she wanted...
# 20 2019-11-27                      The media could not be loa...
# 21 2019-06-08         This phone is actually not fully unlocked!
# 22 2020-07-22  Phone is not unlocked to carriers and when you...
# 23 2019-07-30  this refurbished phone is awesome! i got mine ...
# 24 2020-09-23  The iPhone XR came in quickly and in great con...
# 25 2019-06-27  The phone didn't come in an apple box, but the...
# 26 2019-05-25  I LOVE the phoneXR had it for 2+ weeks and it ...
# 27 2021-05-13  After spending a day setting up my "new" iPhon...
# 28 2020-11-05  I specifically bought from this seller because...
# 29 2019-06-09  I got mine last Sunday and it’s amazing so far...
# 30 2019-09-06  So my wife was in the market for a new iPhone,...
# 31 2021-05-13  I bought 2 of these iPhone XR's.  My sons was ...
# 32 2019-08-14  La verdad tenia muchas dudas, compre este celu...
# 33 2019-07-12  Despite all the reviews saying that this devic...
# 34 2019-05-26  It arrived on time, I bought for my son, it ha...
# 35 2020-06-17  I am wanting a FULL REFUND. This phone is STOL...
# 36 2019-08-18  in near perfect condition, almost no sign of u...
# 37 2019-11-29  Don’t buy this phone!!!! I bought a beautiful ...
# 38 2020-02-11                  Bought for my son and he loves it
# 39 2019-06-01  El teléfono parece en buen estado, pero no tra...
# 40 2020-06-03  This is my first phone purchase in almost a de...
# 41 2019-09-06  Honestly blown away!!!! Beautiful condition. N...
# 42 2019-12-15  I figured with the description of such slight ...
# 43 2019-09-23  This was a gift for my sister's birthday. Work...
# 44 2019-06-25  The phone is perfect just wish it came with a ...
# 45 2020-01-09                      The media could not be loa...
# 46 2020-06-25  I was very hesitant to buy this product, but I...
# 47 2019-09-20  This is a beautiful iPhone however I had some ...
# 48 2020-05-12  the phone came with no box and no headset and ...
# 49 2019-12-06  I love how A good price I got this phone for i...

# %%
df2 = pd.DataFrame()
df2["text"] = df["text"].apply(lambda x: preprocessing(x, list_format=False))
df2["date"] = df["date"]
# Out:
# /var/folders/s4/671kyfms3wnc45z745cx9dc00000gn/T/ipykernel_35988/1015505189.py:11: DeprecationWarning: 'emoji.get_emoji_regexp()' is deprecated and will be removed in version 2.0.0. If you want to remove emoji from a string, consider the method emoji.replace_emoji(str, replace='').
# To hide this warning, pin/downgrade the package to 'emoji~=1.6.3'
#   return emoji.get_emoji_regexp().sub(u'', string)

df2.texts

# %%
import re

df2.dtypes
df2.text = df2.text.apply(lambda x: re.sub('i', '', x))

# %%
df2
# Out:
#                                                  text       date  sentiment
# 0    was a lttle sceptcal buyng ths phone because ... 2019-04-27          2
# 1   ths seller s amazng was a bt skeptcal at frst ... 2019-06-12          2
# 2   just was told by my carrer att that ths phone ... 2019-08-20          0
# 3    purchased ths phone for my daughter and t cam... 2019-05-14          1
# 4    don’t know why everyone’s gvng ths seller a b... 2019-05-21          2
# 5                       the meda could not be load... 2019-06-10          0
# 6   receved my phone a few days ago and everythng ... 2019-05-21          2
# 7        absolutly loved ths phone xr t was wonderful 2019-04-03          2
# 8   ’ll admt after readng through the revews  was ... 2019-08-15          2
# 9   update   stll have ths phone stll works amazng... 2019-08-14          1
# 10   purchased ths red xr about  weeks ago  fnally... 2019-07-03          0
# 11  back was cracked n several places screen sever... 2019-06-10          1
# 12  t took a lttle whle for t to arrve but other t... 2019-05-09          0
# 13  please do not buy ths phone they say that the ... 2019-07-27          2
# 14   love how t was super ntact on the outsde but ... 2019-05-31          1
# 15  pésmo el teléfono vno bloqueado con clave y co... 2019-05-18          0
# 16  worlds worst thng ever never get on ths ts a scam 2019-05-20          2
# 17  phone looks lterally brand new no cracks work ... 2019-07-09          0
# 18  descrbed as “fully unlocked” receved t n excel... 2019-04-12          2
# 19  just what  needed for my teenager she wanted a... 2020-03-05          0
# 20                      the meda could not be load... 2019-11-27          0
# 21            ths phone s actually not fully unlocked 2019-06-08          0
# 22  phone s not unlocked to carrers and when you t... 2020-07-22          0
# 23  ths refurbshed phone s awesome  got mne from c... 2019-07-30          2
# 24  the phone xr came n quckly and n great condton... 2020-09-23          2
# 25  the phone ddnt come n an apple box but the box... 2019-06-27          1
# 26   love the phonexr had t for  weeks and t works... 2019-05-25          2
# 27  after spendng a day settng up my new phone xr ... 2021-05-13          0
# 28   specfcally bought from ths seller because the... 2020-11-05          0
# 29   got mne last sunday and t’s amazng so far whe... 2019-06-09          2
# 30  so my wfe was n the market for a new phone upg... 2019-09-06          1
# 31   bought  of these phone xrs  my sons was great... 2021-05-13          2
# 32  la verdad tena muchas dudas compre este celula... 2019-08-14          1
# 33  despte all the revews sayng that ths devce s f... 2019-07-12          2
# 34  t arrved on tme  bought for my son t has great... 2019-05-26          2
# 35   am wantng a full refund ths phone s stolen  j... 2020-06-17          0
# 36  n near perfect condton almost no sgn of use th... 2019-08-18          2
# 37  don’t buy ths phone  bought a beautful blue co... 2019-11-29          0
# 38                   bought for my son and he loves t 2020-02-11          1
# 39  el teléfono parece en buen estado pero no traí... 2019-06-01          2
# 40  ths s my frst phone purchase n almost a decade... 2020-06-03          1
# 41  honestly blown away beautful condton not one s... 2019-09-06          2
# 42   fgured wth the descrpton of such slght defect... 2019-12-15          1
# 43  ths was a gft for my ssters brthday worked lke... 2019-09-23          1
# 44  the phone s perfect just wsh t came wth a good... 2019-06-25          1
# 45                      the meda could not be load... 2020-01-09          1
# 46   was very hestant to buy ths product but  took... 2020-06-25          0
# 47  ths s a beautful phone however  had some ssues... 2019-09-20          2
# 48  the phone came wth no box and no headset and n... 2020-05-12          0
# 49   love how a good prce  got ths phone for ts ju... 2019-12-06          2

# %%
input_list = df2.values.tolist()
input_list

# %%
google univeral encoder (512 dim)
simple knn clustering
t-sne

Word Cloud 
Google translater API
