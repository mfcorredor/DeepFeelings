# %%
from amzwbscr_selenium import scrape_amz

# %%
product_ids = ["B08BGD4G36", "B09DFCB66S", "B07DBL9TM7"]
mapper = {"iPhone" : "df_B08BGD4G36.csv", "PlayStation" : "df_B09DFCB66S.csv", "sneakers" : "df_B07DBL9TM7.csv"}

# %%
for i in product_ids:
    df = scrape_amz(i)
    df.to_csv(f"df_{i}.csv")
# Out:
# page 1 of 5 scraped
# page 2 of 5 scraped
# page 3 of 5 scraped
# page 4 of 5 scraped
# page 5 of 5 scraped
# page 1 of 5 scraped
# page 2 of 5 scraped
# page 3 of 5 scraped
# page 4 of 5 scraped
# page 5 of 5 scraped
# page 1 of 5 scraped
# page 2 of 5 scraped
# page 3 of 5 scraped
# page 4 of 5 scraped
# page 5 of 5 scraped

# %%
df = pd.read_csv("../raw_data/df_B07DBL9TM7.csv")

# %%
from preproc import get_preproc

# %%
df2 = get_preproc(df)
df2 = get_important_words(df2)
df2
# Out:
#     Unnamed: 0        date                                               text  \
# 0            0  2019-04-08  they are both comfortable and notice the amoun...
# 1            1  2019-03-11  ordered once i have worn size for they were to...
# 2            2  2019-09-12  the showing the black shoe with white are very...
# 3            3  2019-08-17  the popular campus style sneaker that is curre...
# 4            4  2020-01-23  they fit like a glove very comfortable shoe we...
# 5            5  2019-04-18  i really love the look of these but they run i...
# 6            6  2019-03-05              husband of and we always go up a half
# 7            7  2019-07-16  i love these glad bought always these when i w...
# 8            8  2019-03-12  go wrong with this i got the white first i was...
# 9            9  2020-01-29  i bought a half a size because i read the and ...
# 10          10  2019-07-31  went up half a size and still like a surgical ...
# 11          11  2019-07-24  six after the they are already ripping my husb...
# 12          12  2021-06-29  the media could not be i ordered the plain one...
# 13          13  2021-08-06  i like that i for white with black but was sen...
# 14          14  2021-07-14  i bought these because i really like their but...
# 15          16  2020-02-06  since or so of previous proper i the who had m...
# 16          17  2019-11-23  ordered suede see pic and pic of description o...
# 17          18  2020-03-07  i wish id more attention to the tongue of this...
# 18          19  2019-11-05  i wear either an or a in in these a solid they...
# 19          20  2022-01-11  comfortable and very sturdy and say how durabl...
# 20          21  2022-04-05  i really to like these grand court tennis they...
# 21          22  2019-06-26  its like walking on very comfortable these are...
# 22          23  2021-03-20  the first and foremost thing i about these whe...
# 23          24  2021-08-12  i am a big fan of and their but this one perfo...
# 24          25  2021-07-12  this shoe was a return and rated as only in go...
# 25          26  2020-03-03  had my for a week for the money they i have an...
# 26          27  2020-10-19  i expect it to be very good for i almost reall...
# 27          28  2020-11-28  these fit as but they definitely take much tim...
# 28          29  2022-05-15  no wear near as good as they use to i feel sor...
# 29          30  2020-05-27  i this for my husband and he he them all the t...
# 30          31  2021-07-21  the media could not be pretty cool too say the...
# 31          32  2020-11-03  had these for and they been subjected to heavy...
# 32          33  2021-09-20  i play but when i bought a new iridium silver ...
# 33          34  2019-10-19  bought these because the deal was so good just...
# 34          35  2022-04-12  i what to but this shoe was so it pretty much ...
# 35          36  2020-10-06  these look and feel great and there not too aw...
# 36          37  2021-09-04  i ordered the for my but got the normal cant r...
# 37          38  2020-10-04  so this is actually my second pair of that are...
# 38          39  2022-02-10  i use these for my and to throw at people that...
# 39          40  2021-02-17  the product fit graph to be four of the first ...
# 40          41  2021-11-11  been wearing these for a couple of on a limite...
# 41          42  2020-04-05  i am not sure what people expect for a pretty ...
# 42          43  2020-09-05  to preface i am used to to be more specific th...
# 43          44  2020-10-07  these match a lot of my they go with most out ...
# 44          45  2021-12-29  even after seller to inquire which material th...
# 45          46  2021-11-10  a hard time getting used to i hope it worn a s...
# 46          47  2021-03-16  love the sole and nice quality and addition to...
# 47          48  2022-06-05  getting more and more difficult to find a gym ...
# 48          49  2021-06-30  love these gotten on them every day since i go...
#
#                                       important_words
# 0   comfortable notice amount attention opposite s...
# 1   ordered worn size sent got still discovered mu...
# 2   showing black shoe white top photo leather mat...
# 3   popular campus style sneaker currently resembl...
# 4   fit like glove comfortable shoe well put toget...
# 5   really love look run wish got half size stretc...
# 6                              husband always go half
# 7   love glad bought always wa grade finally enoug...
# 8   go wrong got white first wa alarmed fit might ...
# 9   bought half size read took previous got size h...
# 10  went half size still like surgical glove toe l...
# 11  six already ripping husband maybe time week go...
# 12  medium could ordered plain one looking give or...
# 13  like white black wa sent like said leather rec...
# 14  bought really like unfortunately material hard...
# 15  since previous proper make normally wear size ...
# 16  ordered suede see pic pic description ordered ...
# 17  wish id attention tongue foam covered otherwis...
# 18  wear either solid run bit smaller great casual...
# 19  comfortable sturdy say durable thing since cou...
# 20  really like grand court tennis well made quali...
# 21  like walking comfortable like pair purchase no...
# 22  first foremost thing found aside fact since hi...
# 23  big fan one perform bought two vacation break ...
# 24  shoe wa return rated good took chance since wa...
# 25  week money average width foot bit also took br...
# 26  expect good almost really want like wa actuall...
# 27  fit definitely take much time break right foot...
# 28  wear near good use feel sorry people born high...
# 29  husband time thanks everyday boasting comforta...
# 30  medium could pretty cool say wear size average...
# 31  subjected heavy even daily well got black canv...
# 32  play bought new iridium silver knew new pair s...
# 33  bought deal wa good even though really need wa...
# 34  shoe wa pretty much tried cut toe tried soften...
# 35  look feel great awfully sole comfortable think...
# 36  ordered got normal cant return cause live u co...
# 37  actually second pair totally unwearable despit...
# 38  use throw people piss really comfortable first...
# 39  product fit graph four first wear every shoe w...
# 40  wearing couple limited found bit lot uncomfort...
# 41  sure people expect pretty cheap pair retail ch...
# 42  preface used specific classic sneaker grab wou...
# 43  match lot go casual go class take beating with...
# 44  even seller inquire material shoe would made f...
# 45  hard time getting used hope worn size shoe len...
# 46  love sole nice quality addition sole great way...
# 47  getting difficult find gym shoe similar leathe...
# 48  love gotten every day since got pretty comfort...

# %%
df3 = get_kmeans_clusters(df2)
# Out:
# /Users/jannick/.pyenv/versions/3.8.13/envs/project_name/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/jannick/.pyenv/versions/3.8.13/envs/project_name/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
df3
# Out:
#     Unnamed: 0        date                                               text  \
# 0            0  2019-04-08  they are both comfortable and notice the amoun...
# 1            1  2019-03-11  ordered once i have worn size for they were to...
# 2            2  2019-09-12  the showing the black shoe with white are very...
# 3            3  2019-08-17  the popular campus style sneaker that is curre...
# 4            4  2020-01-23  they fit like a glove very comfortable shoe we...
# 5            5  2019-04-18  i really love the look of these but they run i...
# 6            6  2019-03-05              husband of and we always go up a half
# 7            7  2019-07-16  i love these glad bought always these when i w...
# 8            8  2019-03-12  go wrong with this i got the white first i was...
# 9            9  2020-01-29  i bought a half a size because i read the and ...
# 10          10  2019-07-31  went up half a size and still like a surgical ...
# 11          11  2019-07-24  six after the they are already ripping my husb...
# 12          12  2021-06-29  the media could not be i ordered the plain one...
# 13          13  2021-08-06  i like that i for white with black but was sen...
# 14          14  2021-07-14  i bought these because i really like their but...
# 15          16  2020-02-06  since or so of previous proper i the who had m...
# 16          17  2019-11-23  ordered suede see pic and pic of description o...
# 17          18  2020-03-07  i wish id more attention to the tongue of this...
# 18          19  2019-11-05  i wear either an or a in in these a solid they...
# 19          20  2022-01-11  comfortable and very sturdy and say how durabl...
# 20          21  2022-04-05  i really to like these grand court tennis they...
# 21          22  2019-06-26  its like walking on very comfortable these are...
# 22          23  2021-03-20  the first and foremost thing i about these whe...
# 23          24  2021-08-12  i am a big fan of and their but this one perfo...
# 24          25  2021-07-12  this shoe was a return and rated as only in go...
# 25          26  2020-03-03  had my for a week for the money they i have an...
# 26          27  2020-10-19  i expect it to be very good for i almost reall...
# 27          28  2020-11-28  these fit as but they definitely take much tim...
# 28          29  2022-05-15  no wear near as good as they use to i feel sor...
# 29          30  2020-05-27  i this for my husband and he he them all the t...
# 30          31  2021-07-21  the media could not be pretty cool too say the...
# 31          32  2020-11-03  had these for and they been subjected to heavy...
# 32          33  2021-09-20  i play but when i bought a new iridium silver ...
# 33          34  2019-10-19  bought these because the deal was so good just...
# 34          35  2022-04-12  i what to but this shoe was so it pretty much ...
# 35          36  2020-10-06  these look and feel great and there not too aw...
# 36          37  2021-09-04  i ordered the for my but got the normal cant r...
# 37          38  2020-10-04  so this is actually my second pair of that are...
# 38          39  2022-02-10  i use these for my and to throw at people that...
# 39          40  2021-02-17  the product fit graph to be four of the first ...
# 40          41  2021-11-11  been wearing these for a couple of on a limite...
# 41          42  2020-04-05  i am not sure what people expect for a pretty ...
# 42          43  2020-09-05  to preface i am used to to be more specific th...
# 43          44  2020-10-07  these match a lot of my they go with most out ...
# 44          45  2021-12-29  even after seller to inquire which material th...
# 45          46  2021-11-10  a hard time getting used to i hope it worn a s...
# 46          47  2021-03-16  love the sole and nice quality and addition to...
# 47          48  2022-06-05  getting more and more difficult to find a gym ...
# 48          49  2021-06-30  love these gotten on them every day since i go...
#
#                                       important_words  clusters           x  \
# 0   comfortable notice amount attention opposite s...         3  100.155701
# 1   ordered worn size sent got still discovered mu...         3   65.589966
# 2   showing black shoe white top photo leather mat...         2 -171.999344
# 3   popular campus style sneaker currently resembl...         2  133.877426
# 4   fit like glove comfortable shoe well put toget...         2  -87.775246
# 5   really love look run wish got half size stretc...         1 -126.614441
# 6                              husband always go half         0  -64.489426
# 7   love glad bought always wa grade finally enoug...         2  -60.618599
# 8   go wrong got white first wa alarmed fit might ...         1   22.722551
# 9   bought half size read took previous got size h...         3   21.944021
# 10  went half size still like surgical glove toe l...         1   11.571593
# 11  six already ripping husband maybe time week go...         3  -64.291801
# 12  medium could ordered plain one looking give or...         3   80.846481
# 13  like white black wa sent like said leather rec...         3  -41.624805
# 14  bought really like unfortunately material hard...         1   25.311298
# 15  since previous proper make normally wear size ...         1   75.791351
# 16  ordered suede see pic pic description ordered ...         3 -144.609558
# 17  wish id attention tongue foam covered otherwis...         2 -111.030342
# 18  wear either solid run bit smaller great casual...         2  -84.337128
# 19  comfortable sturdy say durable thing since cou...         1   81.973869
# 20  really like grand court tennis well made quali...         1    4.942923
# 21  like walking comfortable like pair purchase no...         1  -42.628010
# 22  first foremost thing found aside fact since hi...         1  -27.920303
# 23  big fan one perform bought two vacation break ...         1   93.795586
# 24  shoe wa return rated good took chance since wa...         1  -56.443626
# 25  week money average width foot bit also took br...         1  -57.553902
# 26  expect good almost really want like wa actuall...         1   49.101528
# 27  fit definitely take much time break right foot...         1  -25.943350
# 28  wear near good use feel sorry people born high...         1  132.366211
# 29  husband time thanks everyday boasting comforta...         3   53.748020
# 30  medium could pretty cool say wear size average...         3  114.269257
# 31  subjected heavy even daily well got black canv...         1 -121.094551
# 32  play bought new iridium silver knew new pair s...         1  141.037720
# 33  bought deal wa good even though really need wa...         3  -27.686007
# 34  shoe wa pretty much tried cut toe tried soften...         1   23.641018
# 35  look feel great awfully sole comfortable think...         1   59.186474
# 36  ordered got normal cant return cause live u co...         3  -89.204346
# 37  actually second pair totally unwearable despit...         1    3.256241
# 38  use throw people piss really comfortable first...         1  -17.856718
# 39  product fit graph four first wear every shoe w...         1   61.244087
# 40  wearing couple limited found bit lot uncomfort...         1  -95.150757
# 41  sure people expect pretty cheap pair retail ch...         2  -29.284189
# 42  preface used specific classic sneaker grab wou...         1   -1.005115
# 43  match lot go casual go class take beating with...         2  -12.744662
# 44  even seller inquire material shoe would made f...         1 -128.814926
# 45  hard time getting used hope worn size shoe len...         1   41.810047
# 46  love sole nice quality addition sole great way...         1  -54.550983
# 47  getting difficult find gym shoe similar leathe...         1  -28.284773
# 48  love gotten every day since got pretty comfort...         1   33.028713
#
#              y
# 0  -137.115143
# 1     6.696075
# 2    -7.245495
# 3    68.743912
# 4   -51.776604
# 5   -82.888466
# 6   149.199585
# 7  -134.031479
# 8  -166.163742
# 9   -89.701164
# 10   56.511166
# 11   46.818314
# 12  127.871460
# 13 -183.151245
# 14  -35.680084
# 15   41.997566
# 16   22.265482
# 17 -158.897232
# 18  -96.865570
# 19  -60.891617
# 20   13.975836
# 21  -96.904144
# 22  -38.618584
# 23  -15.045401
# 24  -26.874126
# 25    7.571867
# 26  -61.003448
# 27   -3.179018
# 28   13.591156
# 29 -106.951981
# 30  -94.942039
# 31  -29.555014
# 32  -49.750034
# 33   30.994070
# 34  106.422150
# 35  -30.034151
# 36   91.554939
# 37  -52.814617
# 38  -78.670990
# 39   75.828789
# 40    4.062895
# 41   70.600632
# 42  -21.987040
# 43 -124.610435
# 44   52.362881
# 45   34.512657
# 46  -62.987221
# 47  120.235931
# 48   -2.027362

# %%
df4 = get_tf_idf_clusters(df2)
# Out:
# /Users/jannick/.pyenv/versions/3.8.13/envs/project_name/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/jannick/.pyenv/versions/3.8.13/envs/project_name/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/jannick/.pyenv/versions/3.8.13/envs/project_name/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
df4
# Out:
#                                                  text  clusters          x  \
# 0   they are both comfortable and notice the amoun...         2 -60.751900
# 1   ordered once i have worn size for they were to...         1  34.343510
# 2   the showing the black shoe with white are very...         0 -18.900841
# 3   the popular campus style sneaker that is curre...         2 -59.831249
# 4   they fit like a glove very comfortable shoe we...         0  26.233772
# 5   i really love the look of these but they run i...         1  53.143650
# 6               husband of and we always go up a half         3  61.915134
# 7   i love these glad bought always these when i w...         3   5.831897
# 8   go wrong with this i got the white first i was...         1  77.174202
# 9   i bought a half a size because i read the and ...         1  24.183868
# 10  went up half a size and still like a surgical ...         1  46.698597
# 11  six after the they are already ripping my husb...         1  46.460358
# 12  the media could not be i ordered the plain one...         1 -16.688934
# 13  i like that i for white with black but was sen...         0 -42.511463
# 14  i bought these because i really like their but...         0 -19.834356
# 15  since or so of previous proper i the who had m...         0  52.081482
# 16  ordered suede see pic and pic of description o...         0  96.992737
# 17  i wish id more attention to the tongue of this...         1  -9.309966
# 18  i wear either an or a in in these a solid they...         0 -15.203104
# 19  comfortable and very sturdy and say how durabl...         0  32.276302
# 20  i really to like these grand court tennis they...         2 -52.987919
# 21  its like walking on very comfortable these are...         0  67.297073
# 22  the first and foremost thing i about these whe...         0  -0.506872
# 23  i am a big fan of and their but this one perfo...         0 -16.351299
# 24  this shoe was a return and rated as only in go...         0 -28.645664
# 25  had my for a week for the money they i have an...         0 -33.538589
# 26  i expect it to be very good for i almost reall...         1  13.667427
# 27  these fit as but they definitely take much tim...         1   8.651083
# 28  no wear near as good as they use to i feel sor...         0  33.307762
# 29  i this for my husband and he he them all the t...         1  35.323551
# 30  the media could not be pretty cool too say the...         1 -23.834248
# 31  had these for and they been subjected to heavy...         1 -13.264393
# 32  i play but when i bought a new iridium silver ...         2 -70.820801
# 33  bought these because the deal was so good just...         0 -68.739014
# 34  i what to but this shoe was so it pretty much ...         1  17.723797
# 35  these look and feel great and there not too aw...         1  11.315948
# 36  i ordered the for my but got the normal cant r...         1  -7.085171
# 37  so this is actually my second pair of that are...         1   6.921376
# 38  i use these for my and to throw at people that...         0  -8.002812
# 39  the product fit graph to be four of the first ...         1  17.925974
# 40  been wearing these for a couple of on a limite...         0 -54.139839
# 41  i am not sure what people expect for a pretty ...         1  53.088158
# 42  to preface i am used to to be more specific th...         0  -0.097896
# 43  these match a lot of my they go with most out ...         0 -45.672607
# 44  even after seller to inquire which material th...         1  73.214485
# 45  a hard time getting used to i hope it worn a s...         2 -36.859596
# 46  love the sole and nice quality and addition to...         0  29.727989
# 47  getting more and more difficult to find a gym ...         3  46.896969
# 48  love these gotten on them every day since i go...         0 -31.971796
#
#              y
# 0   -50.450951
# 1   -11.288732
# 2   -53.783440
# 3    20.673964
# 4   -95.599289
# 5   -81.906494
# 6    64.416054
# 7   -67.249458
# 8    21.231188
# 9   -31.302210
# 10  -23.869457
# 11  -53.768814
# 12   68.137085
# 13  -71.550369
# 14  -33.016811
# 15   26.701765
# 16  -12.838216
# 17 -106.027367
# 18  -82.405800
# 19   14.858598
# 20   -4.442867
# 21  -13.216318
# 22   -2.246301
# 23   -4.284163
# 24  -16.448650
# 25    2.305491
# 26   31.819277
# 27  -48.394505
# 28   34.163860
# 29  -44.636845
# 30   45.645954
# 31   13.483336
# 32    2.286878
# 33  -24.809814
# 34   55.384228
# 35  -17.766073
# 36   35.865742
# 37   14.455090
# 38  -20.159611
# 39   -1.019683
# 40   48.466038
# 41    3.601737
# 42  -33.798843
# 43  -23.289959
# 44  -42.638153
# 45  -41.439045
# 46  -74.167870
# 47   58.301842
# 48   23.264030

# %%
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
import plotly.express as px
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import string

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def lemmatize(text_list):
    result = []
    for i in text_list:
        result.append(lemmatizer.lemmatize(i))
    return result

def remove_stop(text_list):
    result = []
    for i in text_list:
        if i in stop_words:
            pass
        elif i == None or "":
            pass
        else:
            result.append(i)
    return result

#remove all punctuation
def remove_punct(text):
    for p in string.punctuation:
        text = text.replace(p, '')
    return text


#preprocess to get most important words in main df column or just as a list
def get_important_words(df, list_output = False):
    df["important_words"] = df["text"].apply(lambda x: x.split(" "))
    df["important_words"] = df["important_words"].apply(lambda x: lemmatize(x))
    df["important_words"] = df["important_words"].apply(lambda x: remove_stop(x))
    df["important_words"] = df["important_words"].apply(lambda x: " ".join(x))
    df["important_words"] = df["important_words"].apply(lambda x: remove_punct(x))

    result = df

    if list_output:
        temp_df = pd.DataFrame()
        temp_df["text"] = df["important_words"]

        list_of_lists_for_each_text = temp_df.values.tolist()
        list_of_strings_for_each_text = []

        for i in list_of_lists_for_each_text:
            list_of_strings_for_each_text.append("".join(i))

        result = list_of_strings_for_each_text

    return result


def get_list_of_strings(df, column_name = "text"):
    temp_df = pd.DataFrame()
    temp_df["text"] = df[column_name]

    list_of_lists_for_each_text = temp_df.values.tolist()
    list_of_strings_for_each_text = []

    for i in list_of_lists_for_each_text:
        list_of_strings_for_each_text.append("".join(i))

    result = list_of_strings_for_each_text

    return result

# %%
def get_kmeans_clusters(df, n_clusters = 4, perplexity = 30):
    kmeans = KMeans(n_clusters = n_clusters)
    input_list = get_list_of_strings(df) #preprocessing to list
    
    #getting the GSE model
    model_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
    model = hub.load(model_url)

    #getting the GSE vectors
    X = model(input_list)
    array = np.array(X)
    vec_df = pd.DataFrame(array)

    #getting the clusters
    y_pred = kmeans.fit_predict(X)
    df["clusters"] = y_pred
    result_df = df
    
   #reshape to 2dim
    tsne = TSNE(n_components= 2, perplexity= perplexity)
    X_2d = tsne.fit_transform(X)
    X_2d_df = pd.DataFrame(X_2d)

    #final df
    result_df["x"] = X_2d_df[0]
    result_df["y"] = X_2d_df[1]
    
    return result_df

# %%
def get_tf_idf_clusters(df, n_clusters = 4, perplexity = 30, important_words_input = True):
    kmeans = KMeans(n_clusters = n_clusters)


    #creating a list of strings depending on the input column
    if important_words_input:
        list_of_strings = get_list_of_strings(df, column_name = "text")
    else:
        list_of_strings = get_list_of_strings(df, column_name = "important_words")

    bow_df = pd.DataFrame(list_of_strings)
    bow_df.rename(axis = 1, mapper= {0:"text"},inplace=True)

    #Creating word vectors
    tf_idf_vectorizer = TfidfVectorizer()
    X = tf_idf_vectorizer.fit_transform(list_of_strings)
    bow_vec_df = pd.DataFrame(X.toarray(), columns = tf_idf_vectorizer.get_feature_names())

    #KMeans
    y_pred = kmeans.fit_predict(bow_vec_df)
    bow_df["clusters"] = y_pred
    result_df = bow_df

    #reshape to 2dim
    tsne = TSNE(n_components= 2, perplexity= perplexity)
    X_2d = tsne.fit_transform(X)
    X_2d_df = pd.DataFrame(X_2d)

    #final df
    result_df["x"] = X_2d_df[0]
    result_df["y"] = X_2d_df[1]

    return result_df
